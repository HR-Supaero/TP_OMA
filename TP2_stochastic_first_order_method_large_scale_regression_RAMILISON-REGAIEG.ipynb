# %% [markdown]
# # TP OMA 2: Stochastic first order methods
# > ## RAMILISON Hugo | REGAIEG Mohamed

# %% [markdown]
# ## 1 - Linear regression

# %% [markdown]
# In this pratical exercise, we will train again a linear regression model as in TP1 but using stochastic first order methods as seen in the lectures.
#
# Recall the following:
#
# In general, linear regression model do not require to solve an optimization model as the solution can be derived by inverting the normal equations (if the problem has the right properties). However, in the large scale setting, the inversion of the system required in the normal equation is not possible and approximate solutions are computeed using first order methods.
#
# Given a matrix $A\in\mathbb{R}^{n\times d}$ and $b\in\mathbb{R}^n$, we want to minimize the following objective function
#
# $$f(x)=\frac{1}{2n}\|Ax-b\|^2=\frac{1}{2n}\displaystyle\sum_{i=1}^n(a_i^\top x -b_i)^2$$
#
# One can see the function $f$ is $\mu$ strongly convex with $\mu=\lambda_{min}(\nabla^2 f(x))=\frac{1}{n}\lambda_{min}(A^T A)$ and $L$ smooth with $L=\lambda_{max}(\nabla^2 f(x))=\frac{1}{n}\lambda_{max}(A^T A)$, since here the Hessian matrix is constant, independent of $x$.
#
# When $A^{T} A$ is invertible, which is the case here, then we have a simple closed form solution for (the unique) $x^* = \text{argmin}_{x \in \mathbb{R}^d} f(x)$. Indeed, solving $\nabla f(x^*) = 0$ leads to $x^* = (A^T A)^{-1} A^T b$. However when $n$ and $d$ are large (which is the case in modern "big data" problems), using this formula is prohibitively expensive from a computational viewpoint, hence the necessity of using first order optimization algorithms.
#
# In the examples used in the following, whenever possible, in order to exhibit the convergence rates, we will also compute $f(x^*)$ using the normal equations ($x^*=(A^T A)^{-1} A^T b$).
#
# Additionally, we will also consider regularized version of the least square problem in order to enforce some structure in the solution as seen in the lecture as well (ex: L1 regulatrisation for sparsity, L2 for robustness to data perturbation,...).

# %% [markdown]
# We will first load some useful packages:

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as math
import sklearn as sk
from sklearn.datasets import make_regression

# %% [markdown]
# ### Generating data

# %% [markdown]
# In order to generate regression datasets, we will use a dataset generation function from the wellknown $\text{scikit-learn}$ machine learning python environment. The function documentation is available at  https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_regression.html.
#
# Create (by filling in the code below) a python function that will apply this function in order generate a datasets of $n$ samples of dimension $d$ (number of features).

# %%
def generate_dataset(n,d):
    X,Y = make_regression(n, d, n_informative=100, bias=2, coef=False, noise=10.0)
    return X,Y

# %%
n=10000
d=10

X,Y=generate_dataset(n,d)
print("X=",X)
print("Y=",Y)

A = np.c_[np.ones(n), X]
# Out:
# X= [[-2.1082724  -1.27990517  1.0968229  ... -0.64525005  0.99278276
#   -0.50426197]
#  [ 0.17626449  0.17204832  1.31143588 ... -0.50605933  0.33104325
#   -1.74109964]
#  [-0.31576698  1.08306511 -0.3192093  ... -0.01567884 -0.05623375
#    0.42238111]
#  ...
#  [-0.38866056 -0.86649647  0.97139195 ...  1.00079657  0.26317642
#   -1.64647921]
#  [ 0.49338486  1.08257438  0.33915332 ... -2.95153888 -1.25473314
#    0.04781209]
#  [ 0.79164291  0.36063368 -0.457762   ...  0.48097369 -0.32382245
#    0.47108282]]
# Y= [-101.36205624 -160.01872007  186.48129059 ...  107.49017494  -99.46476664
#   -74.15663255]

# %%
# Define problem constants
eigenvalues, eigenvectors = np.linalg.eig(A.T @ A)  
c = 1/(n)* np.min(eigenvalues)
L= 1/(n)* np.max(eigenvalues)

# %% [markdown]
# ### Computing $f(x^*)$

# %%
def full_objective(Y, A, x):
    # Compute the least squares objective over the whole dataset
    n= Y.shape[0]
    return 1/(2*n)*np.linalg.norm(Y - A @ x)**2

# %%
x_star = np.linalg.solve(A.T@A, A.T@Y)
best_objective = full_objective(Y, A, x_star)
print("f(x*) = ", best_objective)
print(x_star)
# Out:
# f(x*) =  49.36133394790814
# [ 2.08991303 72.07480059 45.97103581 85.97531111 94.94316638 34.96525221
#  64.99632689 72.03855388 79.9039295  99.25629411 97.82091646]

# %% [markdown]
# ### Benchmark: gradient descent

# %%
def gradient_regression(Y, A, x):
    """
    Compute the gradient of the regression function for the entire dataset.
    
    :param Y: a numpy array of shape (n)
    :param A: a numpy array of shape (n, d)
    :param x: compute the gradient at these parameters, numpy array of shape (d)
    
    :return: gradient: numpy array of shape (d)
    """
    
    n = Y.shape[0]
    grad = - (1/n) * A.T @ (Y - A @ x)
    return grad

def gradient_descent(
        Y, 
        A, 
        initial_x, 
        nmax, lr):
    """
    Gradient Descent for Linear Least Squares problems.
    
    :param Y: numpy array of size (n)
    :param A: numpy array of size (n, d)
    :param initial_x: starting parameters, a numpy array of size (d)
    :param nmax: integer, number of iterations
    :param lr: learning rate=step size
    
    
    :return:
    - objectives, a list of loss values on the whole dataset, collected at the end of each pass over the dataset (epoch)
    - param_states, a list of parameter vectors, collected at the end of each pass over the dataset
    """
    xs = [initial_x]  # parameters after each update 
    objectives = []  # loss values after each update
    x = initial_x
    
    for epoch in range(nmax):
        grad = gradient_regression(Y, A, x)
        # update x through the gradient update
        x = x - lr * grad
    
        # store x and objective
        xs.append(x.copy())
        objective = full_objective(Y, A, x)
        objectives.append(objective)
        print("GD({ep:04d}/{bi:04d}/{ti:04d}): objective = {l:10.2f}".format(ep=epoch,
                      bi=epoch, ti=len(Y) - 1, l=objective))
    return objectives, xs

import datetime

# Define the parameters of the algorithm.
nmax = 100
lr=0.1

# Initialization
x_initial = np.zeros(A.shape[1])

# Start GD
start_time = datetime.datetime.now()
gd_objectives, gd_iterates = gradient_descent(
    Y, A, x_initial, nmax, lr)
end_time = datetime.datetime.now()

# Print result
execution_time = (end_time - start_time).total_seconds()
print("GD: execution time={t:.3f} seconds".format(t=execution_time))
# Out:
# GD(0000/0000/9999): objective =   24362.62
# GD(0001/0001/9999): objective =   19750.92
# GD(0002/0002/9999): objective =   16014.70
# GD(0003/0003/9999): objective =   12987.63
# GD(0004/0004/9999): objective =   10534.98
# GD(0005/0005/9999): objective =    8547.67
# GD(0006/0006/9999): objective =    6937.33
# GD(0007/0007/9999): objective =    5632.39
# GD(0008/0008/9999): objective =    4574.88
# GD(0009/0009/9999): objective =    3717.86
# GD(0010/0010/9999): objective =    3023.27
# GD(0011/0011/9999): objective =    2460.31
# GD(0012/0012/9999): objective =    2004.01
# GD(0013/0013/9999): objective =    1634.14
# GD(0014/0014/9999): objective =    1334.32
# GD(0088/0088/9999): objective =      49.36
# GD(0089/0089/9999): objective =      49.36
# GD(0090/0090/9999): objective =      49.36
# GD(0091/0091/9999): objective =      49.36
# GD(0092/0092/9999): objective =      49.36
# GD(0093/0093/9999): objective =      49.36
# GD(0094/0094/9999): objective =      49.36
# GD(0095/0095/9999): objective =      49.36
# GD(0096/0096/9999): objective =      49.36
# GD(0097/0097/9999): objective =      49.36
# GD(0098/0098/9999): objective =      49.36
# GD(0099/0099/9999): objective =      49.36
# GD: execution time=0.253 seconds

# %% [markdown]
# ### Stochastic gradient descent

# %% [markdown]
# Let us first define the gradient function that will be used next in the descent algorithm.

# %%
def minibatch_gradient(Y_batch, A_batch, x):
    """
    Compute a mini-batch stochastic gradient from a subset of `num_examples` from the dataset.
    
    :param Y_batch: a numpy array of shape (batch_size)
    :param A_batch: a numpy array of shape (batch_size, d)
    :param x: compute the mini-batch gradient at these parameters, numpy array of shape (d)
    
    :return: stoc_grad: numpy array of shape (d)
    """
    
    stoc_grad = gradient_regression(Y_batch, A_batch, x)
    return stoc_grad

# %% [markdown]
# Using your gradient function, propose an implementation of the gradient descent to solve the linear regression problem.

# %%
import random as random
def stoc_gradient_descent(
        Y, 
        A, 
        initial_x, 
        nmax, lr, batch_size):
    """
    Stochastic gradient descent for Linear Least Squares problems.
    
    :param Y: numpy array of size (n)
    :param A: numpy array of size (n, d)
    :param initial_x: starting parameters, a numpy array of size (d)
    :param nmax: integer, number of iterations
    :param lr: learning rate=step size
    :param batch_size: number of samples used for calculating the stochastic gradient 
    
    
    :return:
    - objectives, a list of loss values on the whole dataset, collected at the end of each pass over the dataset (epoch)
    - param_states, a list of parameter vectors, collected at the end of each pass over the dataset
    """
    xs = [initial_x]  # parameters after each update 
    objectives = []  # loss values after each update
    x = initial_x
    
    for epoch in range(nmax):
        n=len(Y)
        batch_set = random.sample(range(n), batch_size)
        # index= np.array(batch_set)
        A_batch = A[batch_set,:]
        Y_batch = Y[batch_set]
        stocgrad= minibatch_gradient(Y_batch, A_batch, x)
        
        # update x through the gradient update
        x = x - lr * stocgrad

        # store x and objective
        xs.append(x.copy())
        objective = full_objective(Y, A, x)
        objectives.append(objective)
        print("SGD({ep:04d}/{bi:04d}/{ti:04d}): objective = {l:10.2f}".format(ep=epoch,
                      bi=epoch, ti=len(Y) - 1, l=objective))
    return objectives, xs

# %% [markdown]
# Test now your SGD on the regression problem you have generated earlier. You may try several values for the step size and various type of step sizes (constant, diminishing).

# %%
import datetime

# Define the parameters of the algorithm.
nmax = 100
lr=0.05
batch_size=1

# Initialization
x_initial = np.zeros(A.shape[1])

# Start GD
start_time = datetime.datetime.now()
stocgd_objectives, stocgd_iterates = stoc_gradient_descent(
    Y, A, x_initial, nmax, lr,batch_size)
end_time = datetime.datetime.now()

# Print result
execution_time = (end_time - start_time).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=execution_time))
# Out:
# SGD(0000/0000/9999): objective =   30059.67
# SGD(0001/0001/9999): objective =   28883.82
# SGD(0002/0002/9999): objective =   13352.61
# SGD(0003/0003/9999): objective =   13006.91
# SGD(0004/0004/9999): objective =   11937.45
# SGD(0005/0005/9999): objective =   10895.68
# SGD(0006/0006/9999): objective =   10897.53
# SGD(0007/0007/9999): objective =   10628.33
# SGD(0008/0008/9999): objective =   10620.57
# SGD(0009/0009/9999): objective =    7833.96
# SGD(0010/0010/9999): objective =    6564.62
# SGD(0011/0011/9999): objective =    5588.57
# SGD(0012/0012/9999): objective =    5586.81
# SGD(0013/0013/9999): objective =    5005.70
# SGD(0014/0014/9999): objective =    4988.98
# SGD(0015/0015/9999): objective =    4925.64
# SGD(0016/0016/9999): objective =    4799.46
# SGD(0017/0017/9999): objective =    4783.31
# SGD(0018/0018/9999): objective =    4754.51
# SGD(0019/0019/9999): objective =    4680.18
# SGD(0020/0020/9999): objective =    4664.54
# SGD(0021/0021/9999): objective =    4613.51
# SGD(0022/0022/9999): objective =    4588.78
# SGD(0023/0023/9999): objective =    4569.31
# SGD(0024/0024/9999): objective =    4133.20
# SGD(0025/0025/9999): objective =    4132.83
# SGD(0026/0026/9999): objective =    3244.26
# SGD(0027/0027/9999): objective =    2888.88
# SGD(0028/0028/9999): objective =    2298.01
# SGD(0029/0029/9999): objective =    2246.78
# SGD(0030/0030/9999): objective =    2142.88
# SGD(0031/0031/9999): objective =    2108.87
# SGD(0032/0032/9999): objective =    1947.58
# SGD(0033/0033/9999): objective =    1886.84
# SGD(0034/0034/9999): objective =    1854.80
# SGD(0035/0035/9999): objective =    1757.34
# SGD(0036/0036/9999): objective =    1679.84
# SGD(0037/0037/9999): objective =    1666.93
# SGD(0038/0038/9999): objective =    1452.83
# SGD(0039/0039/9999): objective =    1449.97
# SGD(0040/0040/9999): objective =    1427.24
# SGD(0041/0041/9999): objective =    1422.60
# SGD(0042/0042/9999): objective =    1154.64
# SGD(0043/0043/9999): objective =    1157.10
# SGD(0044/0044/9999): objective =    1151.79
# SGD(0045/0045/9999): objective =    1109.78
# SGD(0046/0046/9999): objective =    1019.15
# SGD(0047/0047/9999): objective =    1006.33
# SGD(0048/0048/9999): objective =     932.78
# SGD(0049/0049/9999): objective =     903.22
# SGD(0050/0050/9999): objective =     884.30
# SGD(0051/0051/9999): objective =     779.57
# SGD(0052/0052/9999): objective =     733.19
# SGD(0053/0053/9999): objective =     731.16
# SGD(0054/0054/9999): objective =     702.25
# SGD(0055/0055/9999): objective =     703.04
# SGD(0056/0056/9999): objective =     707.53
# SGD(0057/0057/9999): objective =     558.57
# SGD(0058/0058/9999): objective =     559.00
# SGD(0059/0059/9999): objective =     558.66
# SGD(0060/0060/9999): objective =     549.05
# SGD(0061/0061/9999): objective =     546.03
# SGD(0062/0062/9999): objective =     438.39
# SGD(0063/0063/9999): objective =     409.12
# SGD(0064/0064/9999): objective =     409.48
# SGD(0065/0065/9999): objective =     395.42
# SGD(0066/0066/9999): objective =     395.00
# SGD(0067/0067/9999): objective =     393.50
# SGD(0068/0068/9999): objective =     391.53
# SGD(0069/0069/9999): objective =     376.75
# SGD(0070/0070/9999): objective =     363.97
# SGD(0071/0071/9999): objective =     347.55
# SGD(0072/0072/9999): objective =     343.74
# SGD(0073/0073/9999): objective =     328.98
# SGD(0074/0074/9999): objective =     323.97
# SGD(0075/0075/9999): objective =     302.62
# SGD(0076/0076/9999): objective =     299.48
# SGD(0077/0077/9999): objective =     299.15
# SGD(0078/0078/9999): objective =     245.27
# SGD(0079/0079/9999): objective =     232.91
# SGD(0080/0080/9999): objective =     205.16
# SGD(0081/0081/9999): objective =     206.41
# SGD(0082/0082/9999): objective =     205.84
# SGD(0083/0083/9999): objective =     193.60
# SGD(0084/0084/9999): objective =     181.23
# SGD(0085/0085/9999): objective =     178.61
# SGD(0086/0086/9999): objective =     178.78
# SGD(0087/0087/9999): objective =     183.29
# SGD(0088/0088/9999): objective =     183.17
# SGD(0089/0089/9999): objective =     179.81
# SGD(0090/0090/9999): objective =     169.12
# SGD(0091/0091/9999): objective =     171.02
# SGD(0092/0092/9999): objective =     149.57
# SGD(0093/0093/9999): objective =     155.10
# SGD(0094/0094/9999): objective =     155.09
# SGD(0095/0095/9999): objective =     107.18
# SGD(0096/0096/9999): objective =     102.34
# SGD(0097/0097/9999): objective =      97.95
# SGD(0098/0098/9999): objective =      95.24
# SGD(0099/0099/9999): objective =      89.18
# SGD: execution time=0.051 seconds

# %% [markdown]
# Let us now plot the convergence profile, i.e. $f(x_t) - f(x^*)$ with respect to the iteration $t$:

# %%
plt.title('Convergence rate')
plt.loglog(stocgd_objectives - best_objective)
plt.xlabel('iteration t')
plt.ylabel(r'$f(x_t) - f(x^*)$')
plt.show()
# test lr comme en cours
# augmente batch size

# %% [markdown]
# #### Constant Learning Rate

# %% [markdown]
# According to the course results, the constant stepsize must satisfy
# $0 < \bar{\alpha} \le \frac{\mu}{L\,M_G}$,
# where $L$ is the Lipschitz constant of the gradient and $M_G$ is related to the
# variance of the stochastic gradient.
#
# In the context of this TP, the stochastic gradient is unbiased, which implies
# $\mu=\mu_G=1$. Moreover, using the variance assumptions, we obtain
# $M_G = M_V + \mu_G^2 = M_V + 1$.
# Hence, the admissible range for the constant stepsize becomes
# $0 < \bar{\alpha} \le \frac{1}{L(1+M_V)}$.

# %%
# Define the parameters of the algorithm.
nmax = 100
lr_values = [1/(i*L) for i in [6, 8, 10, 12, 16]]
objectives_dict = {}

for lr in lr_values:
    objectives, _ = stoc_gradient_descent(Y, A, x_initial, nmax, lr, batch_size)
    objectives_dict[lr] = objectives

for lr, objectives in objectives_dict.items():
    # Plot f(x_t) - f(x^*) on log-log scale
    plt.loglog(np.array(objectives) - best_objective,
               label=f"lr=1/(L*{1/(L*lr):.0f})")

plt.legend()
plt.xlabel("iteration t")
plt.ylabel(r"$f(x_t) - f(x^*)$")
plt.title("Convergence rate for different Learning Rates")
plt.show()
# Out:
# SGD(0000/0000/9999): objective =   21126.71
# SGD(0001/0001/9999): objective =   14844.47
# SGD(0002/0002/9999): objective =   10998.41
# SGD(0003/0003/9999): objective =    7660.46
# SGD(0004/0004/9999): objective =    5332.91
# SGD(0005/0005/9999): objective =    3572.67
# SGD(0006/0006/9999): objective =    2709.89
# SGD(0007/0007/9999): objective =    2095.58
# SGD(0008/0008/9999): objective =    1453.31
# SGD(0009/0009/9999): objective =     971.57
# SGD(0010/0010/9999): objective =     707.16
# SGD(0011/0011/9999): objective =     490.57
# SGD(0012/0012/9999): objective =     344.68
# SGD(0013/0013/9999): objective =     245.02
# SGD(0014/0014/9999): objective =     188.61
# SGD(0015/0015/9999): objective =     139.21
# SGD(0016/0016/9999): objective =     109.22
# SGD(0017/0017/9999): objective =      90.20
# SGD(0018/0018/9999): objective =      78.87
# SGD(0019/0019/9999): objective =      71.66
# SGD(0020/0020/9999): objective =      67.38
# SGD(0021/0021/9999): objective =      60.53
# SGD(0022/0022/9999): objective =      58.71
# SGD(0023/0023/9999): objective =      56.70
# SGD(0024/0024/9999): objective =      54.96
# SGD(0025/0025/9999): objective =      54.10
# SGD(0026/0026/9999): objective =      53.13
# SGD(0027/0027/9999): objective =      52.56
# SGD(0028/0028/9999): objective =      51.76
# SGD(0029/0029/9999): objective =      50.92
# SGD(0030/0030/9999): objective =      50.76
# SGD(0031/0031/9999): objective =      50.70
# SGD(0032/0032/9999): objective =      50.46
# SGD(0033/0033/9999): objective =      50.70
# SGD(0034/0034/9999): objective =      50.52
# SGD(0035/0035/9999): objective =      50.22
# SGD(0036/0036/9999): objective =      49.95
# SGD(0037/0037/9999): objective =      49.82
# SGD(0038/0038/9999): objective =      49.72
# SGD(0039/0039/9999): objective =      49.75
# SGD(0040/0040/9999): objective =      49.64
# SGD(0041/0041/9999): objective =      49.58
# SGD(0042/0042/9999): objective =      49.58
# SGD(0043/0043/9999): objective =      49.66
# SGD(0044/0044/9999): objective =      49.69
# SGD(0045/0045/9999): objective =      49.71
# SGD(0046/0046/9999): objective =      49.51
# SGD(0047/0047/9999): objective =      49.65
# SGD(0048/0048/9999): objective =      49.58
# SGD(0049/0049/9999): objective =      49.77
# SGD(0050/0050/9999): objective =      49.78
# SGD(0051/0051/9999): objective =      49.66
# SGD(0052/0052/9999): objective =      49.74
# SGD(0053/0053/9999): objective =      49.73
# SGD(0054/0054/9999): objective =      49.72
# SGD(0055/0055/9999): objective =      49.86
# SGD(0056/0056/9999): objective =      49.84
# SGD(0057/0057/9999): objective =      49.94
# SGD(0058/0058/9999): objective =      50.06
# SGD(0059/0059/9999): objective =      49.81
# SGD(0060/0060/9999): objective =      49.58
# SGD(0061/0061/9999): objective =      49.55
# SGD(0062/0062/9999): objective =      49.67
# SGD(0063/0063/9999): objective =      49.76
# SGD(0064/0064/9999): objective =      49.76
# SGD(0065/0065/9999): objective =      49.74
# SGD(0066/0066/9999): objective =      49.82
# SGD(0067/0067/9999): objective =      49.77
# SGD(0068/0068/9999): objective =      49.84
# SGD(0069/0069/9999): objective =      49.77
# SGD(0070/0070/9999): objective =      49.74
# SGD(0071/0071/9999): objective =      49.84
# SGD(0072/0072/9999): objective =      49.71
# SGD(0073/0073/9999): objective =      49.65
# SGD(0074/0074/9999): objective =      49.71
# SGD(0075/0075/9999): objective =      49.68
# SGD(0076/0076/9999): objective =      49.60
# SGD(0077/0077/9999): objective =      49.58
# SGD(0078/0078/9999): objective =      49.74
# SGD(0079/0079/9999): objective =      49.70
# SGD(0080/0080/9999): objective =      49.87
# SGD(0081/0081/9999): objective =      49.84
# SGD(0082/0082/9999): objective =      49.69
# SGD(0083/0083/9999): objective =      49.57
# SGD(0084/0084/9999): objective =      49.69
# SGD(0085/0085/9999): objective =      49.85
# SGD(0086/0086/9999): objective =      49.69
# SGD(0087/0087/9999): objective =      49.62
# SGD(0088/0088/9999): objective =      49.77
# SGD(0089/0089/9999): objective =      49.68
# SGD(0090/0090/9999): objective =      49.63
# SGD(0091/0091/9999): objective =      49.86
# SGD(0092/0092/9999): objective =      49.82
# SGD(0093/0093/9999): objective =      49.77
# SGD(0094/0094/9999): objective =      49.56
# SGD(0095/0095/9999): objective =      49.62
# SGD(0096/0096/9999): objective =      49.76
# SGD(0097/0097/9999): objective =      49.67
# SGD(0098/0098/9999): objective =      49.74
# SGD(0099/0099/9999): objective =      49.93
# SGD(0000/0000/9999): objective =   23682.83
# SGD(0001/0001/9999): objective =   18506.85
# SGD(0002/0002/9999): objective =   14457.22
# SGD(0003/0003/9999): objective =   11437.23
# SGD(0004/0004/9999): objective =    9186.76
# SGD(0005/0005/9999): objective =    7069.08
# SGD(0006/0006/9999): objective =    5186.96
# SGD(0007/0007/9999): objective =    3894.13
# SGD(0008/0008/9999): objective =    3140.40
# SGD(0009/0009/9999): objective =    2568.72
# SGD(0010/0010/9999): objective =    1919.25
# SGD(0011/0011/9999): objective =    1545.56
# SGD(0012/0012/9999): objective =    1186.32
# SGD(0013/0013/9999): objective =     945.70
# SGD(0014/0014/9999): objective =     777.92
# SGD(0015/0015/9999): objective =     633.64
# SGD(0016/0016/9999): objective =     521.18
# SGD(0017/0017/9999): objective =     422.66
# SGD(0018/0018/9999): objective =     342.29
# SGD(0019/0019/9999): objective =     284.76
# SGD(0020/0020/9999): objective =     240.42
# SGD(0021/0021/9999): objective =     200.96
# SGD(0022/0022/9999): objective =     161.33
# SGD(0023/0023/9999): objective =     137.98
# SGD(0024/0024/9999): objective =     121.42
# SGD(0025/0025/9999): objective =     107.28
# SGD(0026/0026/9999): objective =      97.49
# SGD(0027/0027/9999): objective =      84.88
# SGD(0028/0028/9999): objective =      76.01
# SGD(0029/0029/9999): objective =      70.27
# SGD(0030/0030/9999): objective =      67.34
# SGD(0031/0031/9999): objective =      63.95
# SGD(0032/0032/9999): objective =      60.40
# SGD(0033/0033/9999): objective =      58.54
# SGD(0034/0034/9999): objective =      56.56
# SGD(0035/0035/9999): objective =      54.94
# SGD(0036/0036/9999): objective =      53.55
# SGD(0037/0037/9999): objective =      52.84
# SGD(0038/0038/9999): objective =      52.07
# SGD(0039/0039/9999): objective =      51.48
# SGD(0040/0040/9999): objective =      50.95
# SGD(0041/0041/9999): objective =      50.76
# SGD(0042/0042/9999): objective =      50.67
# SGD(0043/0043/9999): objective =      50.42
# SGD(0044/0044/9999): objective =      50.35
# SGD(0045/0045/9999): objective =      50.39
# SGD(0046/0046/9999): objective =      50.39
# SGD(0047/0047/9999): objective =      50.20
# SGD(0048/0048/9999): objective =      50.03
# SGD(0049/0049/9999): objective =      49.84
# SGD(0050/0050/9999): objective =      49.65
# SGD(0051/0051/9999): objective =      49.56
# SGD(0052/0052/9999): objective =      49.66
# SGD(0053/0053/9999): objective =      49.68
# SGD(0054/0054/9999): objective =      49.77
# SGD(0055/0055/9999): objective =      49.81
# SGD(0056/0056/9999): objective =      49.92
# SGD(0057/0057/9999): objective =      50.11
# SGD(0058/0058/9999): objective =      50.21
# SGD(0059/0059/9999): objective =      50.43
# SGD(0060/0060/9999): objective =      50.12
# SGD(0061/0061/9999): objective =      50.06
# SGD(0062/0062/9999): objective =      49.98
# SGD(0063/0063/9999): objective =      49.85
# SGD(0064/0064/9999): objective =      49.75
# SGD(0065/0065/9999): objective =      49.61
# SGD(0066/0066/9999): objective =      49.68
# SGD(0067/0067/9999): objective =      49.82
# SGD(0068/0068/9999): objective =      49.77
# SGD(0069/0069/9999): objective =      49.79
# SGD(0070/0070/9999): objective =      49.80
# SGD(0071/0071/9999): objective =      49.74
# SGD(0072/0072/9999): objective =      49.76
# SGD(0073/0073/9999): objective =      49.77
# SGD(0074/0074/9999): objective =      49.82
# SGD(0075/0075/9999): objective =      49.74
# SGD(0076/0076/9999): objective =      49.77
# SGD(0077/0077/9999): objective =      49.89
# SGD(0078/0078/9999): objective =      49.75
# SGD(0079/0079/9999): objective =      49.80
# SGD(0080/0080/9999): objective =      49.78
# SGD(0081/0081/9999): objective =      49.80
# SGD(0082/0082/9999): objective =      49.74
# SGD(0083/0083/9999): objective =      49.67
# SGD(0084/0084/9999): objective =      49.63
# SGD(0085/0085/9999): objective =      49.63
# SGD(0086/0086/9999): objective =      49.68
# SGD(0087/0087/9999): objective =      49.72
# SGD(0088/0088/9999): objective =      49.84
# SGD(0089/0089/9999): objective =      49.81
# SGD(0090/0090/9999): objective =      49.96
# SGD(0091/0091/9999): objective =      49.78
# SGD(0092/0092/9999): objective =      49.77
# SGD(0093/0093/9999): objective =      49.86
# SGD(0094/0094/9999): objective =      49.71
# SGD(0095/0095/9999): objective =      49.76
# SGD(0096/0096/9999): objective =      49.76
# SGD(0097/0097/9999): objective =      49.85
# SGD(0098/0098/9999): objective =      49.80
# SGD(0099/0099/9999): objective =      49.80
# SGD(0000/0000/9999): objective =   24873.11
# SGD(0001/0001/9999): objective =   19695.66
# SGD(0002/0002/9999): objective =   17002.41
# SGD(0003/0003/9999): objective =   14129.68
# SGD(0004/0004/9999): objective =   12077.27
# SGD(0005/0005/9999): objective =    9703.27
# SGD(0006/0006/9999): objective =    7816.40
# SGD(0007/0007/9999): objective =    6065.31
# SGD(0008/0008/9999): objective =    4997.45
# SGD(0009/0009/9999): objective =    3978.20
# SGD(0010/0010/9999): objective =    3290.10
# SGD(0011/0011/9999): objective =    2596.70
# SGD(0012/0012/9999): objective =    2124.06
# SGD(0013/0013/9999): objective =    1782.23
# SGD(0014/0014/9999): objective =    1507.50
# SGD(0015/0015/9999): objective =    1301.21
# SGD(0016/0016/9999): objective =    1101.91
# SGD(0017/0017/9999): objective =     928.09
# SGD(0018/0018/9999): objective =     772.57
# SGD(0019/0019/9999): objective =     662.29
# SGD(0020/0020/9999): objective =     556.57
# SGD(0021/0021/9999): objective =     467.06
# SGD(0022/0022/9999): objective =     387.71
# SGD(0023/0023/9999): objective =     327.27
# SGD(0024/0024/9999): objective =     272.43
# SGD(0025/0025/9999): objective =     221.16
# SGD(0026/0026/9999): objective =     191.42
# SGD(0027/0027/9999): objective =     160.46
# SGD(0028/0028/9999): objective =     145.91
# SGD(0029/0029/9999): objective =     127.96
# SGD(0030/0030/9999): objective =     112.92
# SGD(0031/0031/9999): objective =      96.86
# SGD(0032/0032/9999): objective =      86.79
# SGD(0033/0033/9999): objective =      81.37
# SGD(0034/0034/9999): objective =      74.75
# SGD(0035/0035/9999): objective =      70.44
# SGD(0036/0036/9999): objective =      66.52
# SGD(0037/0037/9999): objective =      63.26
# SGD(0038/0038/9999): objective =      62.26
# SGD(0039/0039/9999): objective =      59.86
# SGD(0040/0040/9999): objective =      58.20
# SGD(0041/0041/9999): objective =      56.90
# SGD(0042/0042/9999): objective =      55.23
# SGD(0043/0043/9999): objective =      54.42
# SGD(0044/0044/9999): objective =      53.41
# SGD(0045/0045/9999): objective =      52.56
# SGD(0046/0046/9999): objective =      51.84
# SGD(0047/0047/9999): objective =      51.14
# SGD(0048/0048/9999): objective =      51.00
# SGD(0049/0049/9999): objective =      50.61
# SGD(0050/0050/9999): objective =      50.41
# SGD(0051/0051/9999): objective =      50.14
# SGD(0052/0052/9999): objective =      49.95
# SGD(0053/0053/9999): objective =      49.78
# SGD(0054/0054/9999): objective =      49.87
# SGD(0055/0055/9999): objective =      49.85
# SGD(0056/0056/9999): objective =      49.82
# SGD(0057/0057/9999): objective =      49.75
# SGD(0058/0058/9999): objective =      49.67
# SGD(0059/0059/9999): objective =      49.51
# SGD(0060/0060/9999): objective =      49.52
# SGD(0061/0061/9999): objective =      49.47
# SGD(0062/0062/9999): objective =      49.51
# SGD(0063/0063/9999): objective =      49.47
# SGD(0064/0064/9999): objective =      49.47
# SGD(0065/0065/9999): objective =      49.44
# SGD(0066/0066/9999): objective =      49.50
# SGD(0067/0067/9999): objective =      49.55
# SGD(0068/0068/9999): objective =      49.51
# SGD(0069/0069/9999): objective =      49.56
# SGD(0070/0070/9999): objective =      49.54
# SGD(0071/0071/9999): objective =      49.53
# SGD(0072/0072/9999): objective =      49.56
# SGD(0073/0073/9999): objective =      49.56
# SGD(0074/0074/9999): objective =      49.53
# SGD(0075/0075/9999): objective =      49.56
# SGD(0076/0076/9999): objective =      49.53
# SGD(0077/0077/9999): objective =      49.45
# SGD(0078/0078/9999): objective =      49.49
# SGD(0079/0079/9999): objective =      49.53
# SGD(0080/0080/9999): objective =      49.57
# SGD(0081/0081/9999): objective =      49.49
# SGD(0082/0082/9999): objective =      49.51
# SGD(0083/0083/9999): objective =      49.57
# SGD(0084/0084/9999): objective =      49.64
# SGD(0085/0085/9999): objective =      49.69
# SGD(0086/0086/9999): objective =      49.69
# SGD(0087/0087/9999): objective =      49.74
# SGD(0088/0088/9999): objective =      49.77
# SGD(0089/0089/9999): objective =      49.73
# SGD(0090/0090/9999): objective =      49.75
# SGD(0091/0091/9999): objective =      49.73
# SGD(0092/0092/9999): objective =      49.83
# SGD(0093/0093/9999): objective =      49.74
# SGD(0094/0094/9999): objective =      49.71
# SGD(0095/0095/9999): objective =      49.55
# SGD(0096/0096/9999): objective =      49.50
# SGD(0097/0097/9999): objective =      49.50
# SGD(0098/0098/9999): objective =      49.51
# SGD(0099/0099/9999): objective =      49.49
# SGD(0000/0000/9999): objective =   26124.80
# SGD(0001/0001/9999): objective =   21759.23
# SGD(0002/0002/9999): objective =   17494.08
# SGD(0003/0003/9999): objective =   14676.07
# SGD(0004/0004/9999): objective =   12529.03
# SGD(0005/0005/9999): objective =   11086.99
# SGD(0006/0006/9999): objective =    9251.32
# SGD(0007/0007/9999): objective =    7957.16
# SGD(0008/0008/9999): objective =    6702.25
# SGD(0009/0009/9999): objective =    5631.69
# SGD(0010/0010/9999): objective =    4792.41
# SGD(0011/0011/9999): objective =    4049.07
# SGD(0012/0012/9999): objective =    3375.85
# SGD(0013/0013/9999): objective =    2879.20
# SGD(0014/0014/9999): objective =    2454.01
# SGD(0015/0015/9999): objective =    2078.97
# SGD(0016/0016/9999): objective =    1729.71
# SGD(0017/0017/9999): objective =    1496.03
# SGD(0018/0018/9999): objective =    1229.80
# SGD(0019/0019/9999): objective =    1055.19
# SGD(0020/0020/9999): objective =     904.68
# SGD(0021/0021/9999): objective =     795.74
# SGD(0022/0022/9999): objective =     681.82
# SGD(0023/0023/9999): objective =     594.41
# SGD(0024/0024/9999): objective =     533.35
# SGD(0025/0025/9999): objective =     479.95
# SGD(0026/0026/9999): objective =     429.28
# SGD(0027/0027/9999): objective =     357.04
# SGD(0028/0028/9999): objective =     310.23
# SGD(0029/0029/9999): objective =     262.46
# SGD(0030/0030/9999): objective =     223.38
# SGD(0031/0031/9999): objective =     205.17
# SGD(0032/0032/9999): objective =     181.61
# SGD(0033/0033/9999): objective =     158.98
# SGD(0034/0034/9999): objective =     140.28
# SGD(0035/0035/9999): objective =     125.76
# SGD(0036/0036/9999): objective =     114.39
# SGD(0037/0037/9999): objective =     106.12
# SGD(0038/0038/9999): objective =      99.84
# SGD(0039/0039/9999): objective =      92.12
# SGD(0040/0040/9999): objective =      84.11
# SGD(0041/0041/9999): objective =      78.38
# SGD(0042/0042/9999): objective =      73.02
# SGD(0043/0043/9999): objective =      69.56
# SGD(0044/0044/9999): objective =      66.39
# SGD(0045/0045/9999): objective =      63.28
# SGD(0046/0046/9999): objective =      60.44
# SGD(0047/0047/9999): objective =      59.10
# SGD(0048/0048/9999): objective =      57.68
# SGD(0049/0049/9999): objective =      56.20
# SGD(0050/0050/9999): objective =      54.83
# SGD(0051/0051/9999): objective =      53.54
# SGD(0052/0052/9999): objective =      52.96
# SGD(0053/0053/9999): objective =      52.60
# SGD(0054/0054/9999): objective =      52.27
# SGD(0055/0055/9999): objective =      51.68
# SGD(0056/0056/9999): objective =      51.37
# SGD(0057/0057/9999): objective =      51.13
# SGD(0058/0058/9999): objective =      50.84
# SGD(0059/0059/9999): objective =      50.68
# SGD(0060/0060/9999): objective =      50.67
# SGD(0061/0061/9999): objective =      50.69
# SGD(0062/0062/9999): objective =      50.68
# SGD(0063/0063/9999): objective =      50.43
# SGD(0064/0064/9999): objective =      50.23
# SGD(0065/0065/9999): objective =      50.05
# SGD(0066/0066/9999): objective =      49.95
# SGD(0067/0067/9999): objective =      49.96
# SGD(0068/0068/9999): objective =      49.77
# SGD(0069/0069/9999): objective =      49.65
# SGD(0070/0070/9999): objective =      49.57
# SGD(0071/0071/9999): objective =      49.55
# SGD(0072/0072/9999): objective =      49.61
# SGD(0073/0073/9999): objective =      49.65
# SGD(0074/0074/9999): objective =      49.67
# SGD(0075/0075/9999): objective =      49.71
# SGD(0076/0076/9999): objective =      49.74
# SGD(0077/0077/9999): objective =      49.70
# SGD(0078/0078/9999): objective =      49.76
# SGD(0079/0079/9999): objective =      49.74
# SGD(0080/0080/9999): objective =      49.62
# SGD(0081/0081/9999): objective =      49.63
# SGD(0082/0082/9999): objective =      49.68
# SGD(0083/0083/9999): objective =      49.71
# SGD(0084/0084/9999): objective =      49.72
# SGD(0085/0085/9999): objective =      49.82
# SGD(0086/0086/9999): objective =      49.90
# SGD(0087/0087/9999): objective =      49.81
# SGD(0088/0088/9999): objective =      49.92
# SGD(0089/0089/9999): objective =      49.79
# SGD(0090/0090/9999): objective =      49.78
# SGD(0091/0091/9999): objective =      49.79
# SGD(0092/0092/9999): objective =      49.57
# SGD(0093/0093/9999): objective =      49.55
# SGD(0094/0094/9999): objective =      49.50
# SGD(0095/0095/9999): objective =      49.48
# SGD(0096/0096/9999): objective =      49.49
# SGD(0097/0097/9999): objective =      49.58
# SGD(0098/0098/9999): objective =      49.58
# SGD(0099/0099/9999): objective =      49.54
# SGD(0000/0000/9999): objective =   25771.47
# SGD(0001/0001/9999): objective =   23493.59
# SGD(0002/0002/9999): objective =   21245.43
# SGD(0003/0003/9999): objective =   18594.22
# SGD(0004/0004/9999): objective =   16486.34
# SGD(0005/0005/9999): objective =   14535.86
# SGD(0006/0006/9999): objective =   12685.03
# SGD(0007/0007/9999): objective =   11597.62
# SGD(0008/0008/9999): objective =   10128.42
# SGD(0009/0009/9999): objective =    8979.10
# SGD(0010/0010/9999): objective =    7866.43
# SGD(0011/0011/9999): objective =    6930.07
# SGD(0012/0012/9999): objective =    6135.76
# SGD(0013/0013/9999): objective =    5517.05
# SGD(0014/0014/9999): objective =    4771.14
# SGD(0015/0015/9999): objective =    4153.68
# SGD(0016/0016/9999): objective =    3602.37
# SGD(0017/0017/9999): objective =    3226.79
# SGD(0018/0018/9999): objective =    2813.28
# SGD(0019/0019/9999): objective =    2460.62
# SGD(0020/0020/9999): objective =    2165.51
# SGD(0021/0021/9999): objective =    1899.29
# SGD(0022/0022/9999): objective =    1727.48
# SGD(0023/0023/9999): objective =    1581.41
# SGD(0024/0024/9999): objective =    1389.83
# SGD(0025/0025/9999): objective =    1265.13
# SGD(0026/0026/9999): objective =    1126.65
# SGD(0027/0027/9999): objective =    1029.57
# SGD(0028/0028/9999): objective =     941.10
# SGD(0029/0029/9999): objective =     859.09
# SGD(0030/0030/9999): objective =     765.76
# SGD(0031/0031/9999): objective =     684.14
# SGD(0032/0032/9999): objective =     610.44
# SGD(0033/0033/9999): objective =     531.99
# SGD(0034/0034/9999): objective =     470.55
# SGD(0035/0035/9999): objective =     419.22
# SGD(0036/0036/9999): objective =     381.58
# SGD(0037/0037/9999): objective =     345.60
# SGD(0038/0038/9999): objective =     306.83
# SGD(0039/0039/9999): objective =     276.41
# SGD(0040/0040/9999): objective =     248.90
# SGD(0041/0041/9999): objective =     223.59
# SGD(0042/0042/9999): objective =     204.34
# SGD(0043/0043/9999): objective =     184.84
# SGD(0044/0044/9999): objective =     172.71
# SGD(0045/0045/9999): objective =     159.55
# SGD(0046/0046/9999): objective =     147.81
# SGD(0047/0047/9999): objective =     138.69
# SGD(0048/0048/9999): objective =     129.50
# SGD(0049/0049/9999): objective =     121.06
# SGD(0050/0050/9999): objective =     112.30
# SGD(0051/0051/9999): objective =     106.18
# SGD(0052/0052/9999): objective =      99.94
# SGD(0053/0053/9999): objective =      94.45
# SGD(0054/0054/9999): objective =      89.85
# SGD(0055/0055/9999): objective =      86.36
# SGD(0056/0056/9999): objective =      82.14
# SGD(0057/0057/9999): objective =      77.51
# SGD(0058/0058/9999): objective =      73.46
# SGD(0059/0059/9999): objective =      70.76
# SGD(0060/0060/9999): objective =      68.60
# SGD(0061/0061/9999): objective =      66.73
# SGD(0062/0062/9999): objective =      64.32
# SGD(0063/0063/9999): objective =      63.27
# SGD(0064/0064/9999): objective =      61.30
# SGD(0065/0065/9999): objective =      60.44
# SGD(0066/0066/9999): objective =      59.46
# SGD(0067/0067/9999): objective =      58.72
# SGD(0068/0068/9999): objective =      57.46
# SGD(0069/0069/9999): objective =      56.58
# SGD(0070/0070/9999): objective =      55.81
# SGD(0071/0071/9999): objective =      54.75
# SGD(0072/0072/9999): objective =      54.10
# SGD(0073/0073/9999): objective =      53.52
# SGD(0074/0074/9999): objective =      52.99
# SGD(0075/0075/9999): objective =      52.80
# SGD(0076/0076/9999): objective =      52.57
# SGD(0077/0077/9999): objective =      52.31
# SGD(0078/0078/9999): objective =      52.08
# SGD(0079/0079/9999): objective =      51.92
# SGD(0080/0080/9999): objective =      51.42
# SGD(0081/0081/9999): objective =      51.44
# SGD(0082/0082/9999): objective =      51.15
# SGD(0083/0083/9999): objective =      51.08
# SGD(0084/0084/9999): objective =      51.06
# SGD(0085/0085/9999): objective =      50.89
# SGD(0086/0086/9999): objective =      50.69
# SGD(0087/0087/9999): objective =      50.56
# SGD(0088/0088/9999): objective =      50.37
# SGD(0089/0089/9999): objective =      50.27
# SGD(0090/0090/9999): objective =      50.32
# SGD(0091/0091/9999): objective =      50.21
# SGD(0092/0092/9999): objective =      50.18
# SGD(0093/0093/9999): objective =      50.21
# SGD(0094/0094/9999): objective =      50.14
# SGD(0095/0095/9999): objective =      50.12
# SGD(0096/0096/9999): objective =      50.06
# SGD(0097/0097/9999): objective =      49.94
# SGD(0098/0098/9999): objective =      49.89
# SGD(0099/0099/9999): objective =      49.82

# %% [markdown]
# We can observe that for **lr = 1/(L*6)** the curve diverges, suggesting that the stepsize condition may not be respected in practice. For smaller values of lr, the objective decreases more steadily. The smaller the learning rate, the smoother the curve is, with fewer oscillations, although the convergence becomes slower.

# %% [markdown]
# #### Diminishing Learning Rate

# %% [markdown]
# Following *Optimization Methods for Large-Scale Machine Learning*
# (Bottou, Curtis, Nocedal, February 12, 2018), we consider a diminishing
# stepsize of the form $\alpha_k = \frac{\beta}{\gamma + k}$, with
# $\beta > \frac{1}{c\mu}$ and $\gamma > 0$. In addition, the initial
# stepsize must satisfy $\alpha_1 < \frac{\mu}{L M_G}$ in order to meet
# the theoretical convergence conditions.

# %%
import random as random
def stoc_gradient_descent_diminishing_lr(
        Y, 
        A, 
        initial_x,
        c, 
        nmax, batch_size):
    """
    Stochastic gradient descent for Linear Least Squares problems.
    
    :param Y: numpy array of size (n)
    :param A: numpy array of size (n, d)
    :param initial_x: starting parameters, a numpy array of size (d)
    :param nmax: integer, number of iterations
    :param batch_size: number of samples used for calculating the stochastic gradient 
    :param c: constant of strong convexity of the objective function
    
    :return:
    - objectives, a list of loss values on the whole dataset, collected at the end of each pass over the dataset (epoch)
    - param_states, a list of parameter vectors, collected at the end of each pass over the dataset
    """
    xs = [initial_x]  # parameters after each update 
    objectives = []  # loss values after each update
    x = initial_x
    betta = 2/c
    gamma = 16/c # to ensure that the initial learning rate is less than mu/(L*MG) for the chosen betta
    for epoch in range(nmax):
        n=len(Y)
        batch_set = random.sample(range(n), batch_size)
        # index= np.array(batch_set)
        A_batch = A[batch_set,:]
        Y_batch = Y[batch_set]
        stocgrad= minibatch_gradient(Y_batch, A_batch, x)
        
        # update x through the gradient update
        lr =betta /(1+epoch+gamma)
        x = x - lr * stocgrad

        # store x and objective
        xs.append(x.copy())
        objective = full_objective(Y, A, x)
        objectives.append(objective)
        print("SGD({ep:04d}/{bi:04d}/{ti:04d}): objective = {l:10.2f}".format(ep=epoch,
                      bi=epoch, ti=len(Y) - 1, l=objective))
    return objectives, xs

# %%
# Define the parameters of the algorithm.
nmax = 100
batch_size=1

# Initialization
x_initial = np.zeros(A.shape[1])

# Start GD
start_time = datetime.datetime.now()
stocgd_objectives_dim_lr, stocgd_iterates_dim_lr = stoc_gradient_descent_diminishing_lr(
    Y, A, x_initial, c, nmax, batch_size)
end_time = datetime.datetime.now()

# Print result
execution_time = (end_time - start_time).total_seconds()
print("SGD: execution time={t:.3f} seconds".format(t=execution_time))
# Out:
# SGD(0000/0000/9999): objective =   28514.34
# SGD(0001/0001/9999): objective =   26372.77
# SGD(0002/0002/9999): objective =   22451.99
# SGD(0003/0003/9999): objective =   22388.55
# SGD(0004/0004/9999): objective =   22273.96
# SGD(0005/0005/9999): objective =   20567.64
# SGD(0006/0006/9999): objective =   19437.47
# SGD(0007/0007/9999): objective =   17915.35
# SGD(0008/0008/9999): objective =   17447.50
# SGD(0009/0009/9999): objective =   17193.86
# SGD(0010/0010/9999): objective =   17035.17
# SGD(0011/0011/9999): objective =   17014.01
# SGD(0012/0012/9999): objective =   16908.76
# SGD(0013/0013/9999): objective =   15997.58
# SGD(0014/0014/9999): objective =   15992.64
# SGD(0015/0015/9999): objective =   15715.77
# SGD(0016/0016/9999): objective =   15710.64
# SGD(0017/0017/9999): objective =   15591.06
# SGD(0018/0018/9999): objective =   15296.88
# SGD(0019/0019/9999): objective =   14896.19
# SGD(0020/0020/9999): objective =   14873.55
# SGD(0021/0021/9999): objective =   14867.10
# SGD(0022/0022/9999): objective =   10113.43
# SGD(0023/0023/9999): objective =    9532.72
# SGD(0024/0024/9999): objective =    7308.72
# SGD(0025/0025/9999): objective =    6852.57
# SGD(0026/0026/9999): objective =    6849.57
# SGD(0027/0027/9999): objective =    6065.41
# SGD(0028/0028/9999): objective =    4926.30
# SGD(0029/0029/9999): objective =    4830.50
# SGD(0030/0030/9999): objective =    4827.38
# SGD(0031/0031/9999): objective =    4820.07
# SGD(0032/0032/9999): objective =    4812.73
# SGD(0033/0033/9999): objective =    4800.36
# SGD(0034/0034/9999): objective =    4800.32
# SGD(0035/0035/9999): objective =    4782.86
# SGD(0036/0036/9999): objective =    4493.70
# SGD(0037/0037/9999): objective =    4499.27
# SGD(0038/0038/9999): objective =    3773.57
# SGD(0039/0039/9999): objective =    3767.09
# SGD(0040/0040/9999): objective =    3596.92
# SGD(0041/0041/9999): objective =    3498.50
# SGD(0042/0042/9999): objective =    3413.12
# SGD(0043/0043/9999): objective =    2483.67
# SGD(0044/0044/9999): objective =    2483.95
# SGD(0045/0045/9999): objective =    2484.95
# SGD(0046/0046/9999): objective =    2390.43
# SGD(0047/0047/9999): objective =    2314.84
# SGD(0048/0048/9999): objective =    2234.37
# SGD(0049/0049/9999): objective =    2233.72
# SGD(0050/0050/9999): objective =    2126.44
# SGD(0051/0051/9999): objective =    2125.72
# SGD(0052/0052/9999): objective =    2088.67
# SGD(0053/0053/9999): objective =    2086.02
# SGD(0054/0054/9999): objective =    2041.01
# SGD(0055/0055/9999): objective =    2041.09
# SGD(0056/0056/9999): objective =    1945.11
# SGD(0057/0057/9999): objective =    1939.00
# SGD(0058/0058/9999): objective =    1845.63
# SGD(0059/0059/9999): objective =    1829.58
# SGD(0060/0060/9999): objective =    1743.61
# SGD(0061/0061/9999): objective =    1710.53
# SGD(0062/0062/9999): objective =    1594.45
# SGD(0063/0063/9999): objective =    1585.88
# SGD(0064/0064/9999): objective =    1584.55
# SGD(0065/0065/9999): objective =    1369.52
# SGD(0066/0066/9999): objective =    1368.74
# SGD(0067/0067/9999): objective =    1368.85
# SGD(0068/0068/9999): objective =    1269.71
# SGD(0069/0069/9999): objective =    1268.75
# SGD(0070/0070/9999): objective =    1260.12
# SGD(0071/0071/9999): objective =    1259.78
# SGD(0072/0072/9999): objective =    1143.47
# SGD(0073/0073/9999): objective =    1137.82
# SGD(0074/0074/9999): objective =    1115.63
# SGD(0075/0075/9999): objective =    1104.32
# SGD(0076/0076/9999): objective =    1020.87
# SGD(0077/0077/9999): objective =    1010.98
# SGD(0078/0078/9999): objective =     970.45
# SGD(0079/0079/9999): objective =     939.90
# SGD(0080/0080/9999): objective =     918.00
# SGD(0081/0081/9999): objective =     897.72
# SGD(0082/0082/9999): objective =     724.53
# SGD(0083/0083/9999): objective =     727.96
# SGD(0084/0084/9999): objective =     720.38
# SGD(0085/0085/9999): objective =     556.38
# SGD(0086/0086/9999): objective =     528.08
# SGD(0087/0087/9999): objective =     527.28
# SGD(0088/0088/9999): objective =     526.13
# SGD(0089/0089/9999): objective =     509.20
# SGD(0090/0090/9999): objective =     504.81
# SGD(0091/0091/9999): objective =     504.29
# SGD(0092/0092/9999): objective =     475.90
# SGD(0093/0093/9999): objective =     475.27
# SGD(0094/0094/9999): objective =     463.53
# SGD(0095/0095/9999): objective =     462.07
# SGD(0096/0096/9999): objective =     461.14
# SGD(0097/0097/9999): objective =     433.87
# SGD(0098/0098/9999): objective =     433.96
# SGD(0099/0099/9999): objective =     433.96
# SGD: execution time=0.039 seconds

# %%
plt.title('Convergence rate gradient descent for diminishing learning rate', fontsize = 20)
plt.loglog(stocgd_objectives_dim_lr - best_objective)
plt.xlabel('iteration t'  , fontsize = 20)
plt.ylabel(r'$f(x_t) - f(x^*)$', fontsize = 20)
# Out:
# Text(0, 0.5, '$f(x_t) - f(x^*)$')

# %% [markdown]
# For this simulation, we choose a diminishing stepsize of the form
# $\alpha_k = \frac{\beta}{\gamma + k}$ with $\beta = \frac{2}{c} >
# \frac{1}{c\mu}$ and $\gamma$ selected such that
# $\alpha_1 < \frac{\mu}{L M_G}$. We can observe a good convergence
# behavior, with a smoother decrease and fewer fluctuations compared to
# the constant stepsize case.

# %% [markdown]
# #### Increasing Batch Size

# %%
# Define the parameters of the algorithm.
nmax = 100
lr=0.05
batch_size_list = [1, 10,100, 1000,n]
objectives_dict = {}

# Initialization
x_initial = np.zeros(A.shape[1])

for batch_size in batch_size_list:
    # Start GD
    print(f"Running SGD with batch size {batch_size}...")
    stocgd_objectives, stocgd_iterates = stoc_gradient_descent(
        Y, A, x_initial, nmax, lr,batch_size)

    objectives_dict[batch_size] = stocgd_objectives

# Print result
for batch_size, objectives in objectives_dict.items():
        if batch_size== n:
              plt.plot(objectives, label=f"full batch_size={batch_size}", linewidth=1)
        else:      
            plt.plot(objectives, label=f"batch_size={batch_size}", linewidth=1)
plt.legend()
plt.xlabel("Iteration")
plt.xscale('log')
plt.ylabel("Objective Value")
plt.title("Objective Value decrease for different Batch Sizes")
plt.show()
print("SGD: execution time={t:.3f} seconds".format(t=execution_time))
# Out:
# Running SGD with batch size 1...
# SGD(0000/0000/9999): objective =   29921.32
# SGD(0001/0001/9999): objective =   28234.86
# SGD(0002/0002/9999): objective =   26123.60
# SGD(0003/0003/9999): objective =   25686.42
# SGD(0004/0004/9999): objective =   22058.54
# SGD(0005/0005/9999): objective =   21610.64
# SGD(0006/0006/9999): objective =   21336.54
# SGD(0007/0007/9999): objective =   19921.03
# SGD(0008/0008/9999): objective =   19824.59
# SGD(0009/0009/9999): objective =   13932.48
# SGD(0010/0010/9999): objective =   13653.96
# SGD(0011/0011/9999): objective =   13621.20
# SGD(0012/0012/9999): objective =   13273.44
# SGD(0013/0013/9999): objective =   13226.55
# SGD(0014/0014/9999): objective =   12918.56
# SGD(0015/0015/9999): objective =    8127.58
# SGD(0016/0016/9999): objective =    8129.78
# SGD(0017/0017/9999): objective =    8125.20
# SGD(0018/0018/9999): objective =    8106.27
# SGD(0019/0019/9999): objective =    7498.59
# SGD(0020/0020/9999): objective =    6045.79
# SGD(0021/0021/9999): objective =    5553.94
# SGD(0022/0022/9999): objective =    5473.15
# SGD(0023/0023/9999): objective =    4364.09
# SGD(0024/0024/9999): objective =    3989.89
# SGD(0025/0025/9999): objective =    3985.36
# SGD(0026/0026/9999): objective =    3906.58
# SGD(0027/0027/9999): objective =    3100.54
# SGD(0028/0028/9999): objective =    3037.57
# SGD(0029/0029/9999): objective =    1795.83
# SGD(0030/0030/9999): objective =    1763.69
# SGD(0031/0031/9999): objective =    1775.60
# SGD(0032/0032/9999): objective =    1544.49
# SGD(0033/0033/9999): objective =    1509.34
# SGD(0034/0034/9999): objective =    1505.90
# SGD(0035/0035/9999): objective =    1506.23
# SGD(0036/0036/9999): objective =    1429.07
# SGD(0037/0037/9999): objective =    1428.95
# SGD(0038/0038/9999): objective =    1424.14
# SGD(0039/0039/9999): objective =    1357.84
# SGD(0040/0040/9999): objective =    1341.35
# SGD(0041/0041/9999): objective =    1194.15
# SGD(0042/0042/9999): objective =    1031.36
# SGD(0043/0043/9999): objective =     618.35
# SGD(0044/0044/9999): objective =     566.99
# SGD(0045/0045/9999): objective =     568.17
# SGD(0046/0046/9999): objective =     560.61
# SGD(0047/0047/9999): objective =     472.30
# SGD(0048/0048/9999): objective =     468.93
# SGD(0049/0049/9999): objective =     438.99
# SGD(0050/0050/9999): objective =     437.30
# SGD(0051/0051/9999): objective =     438.59
# SGD(0052/0052/9999): objective =     436.80
# SGD(0053/0053/9999): objective =     413.42
# SGD(0054/0054/9999): objective =     366.67
# SGD(0055/0055/9999): objective =     366.90
# SGD(0056/0056/9999): objective =     368.51
# SGD(0057/0057/9999): objective =     340.92
# SGD(0058/0058/9999): objective =     336.54
# SGD(0059/0059/9999): objective =     323.48
# SGD(0060/0060/9999): objective =     312.27
# SGD(0061/0061/9999): objective =     274.97
# SGD(0062/0062/9999): objective =     275.21
# SGD(0063/0063/9999): objective =     178.92
# SGD(0064/0064/9999): objective =     177.36
# SGD(0065/0065/9999): objective =     175.75
# SGD(0066/0066/9999): objective =     171.37
# SGD(0067/0067/9999): objective =     157.71
# SGD(0068/0068/9999): objective =     157.05
# SGD(0069/0069/9999): objective =     152.53
# SGD(0070/0070/9999): objective =     153.53
# SGD(0071/0071/9999): objective =     153.34
# SGD(0072/0072/9999): objective =     145.48
# SGD(0073/0073/9999): objective =     145.95
# SGD(0074/0074/9999): objective =     145.07
# SGD(0075/0075/9999): objective =     144.92
# SGD(0076/0076/9999): objective =     145.50
# SGD(0077/0077/9999): objective =     150.26
# SGD(0078/0078/9999): objective =     157.36
# SGD(0079/0079/9999): objective =     158.05
# SGD(0080/0080/9999): objective =     157.80
# SGD(0081/0081/9999): objective =     157.35
# SGD(0082/0082/9999): objective =     158.57
# SGD(0083/0083/9999): objective =     158.85
# SGD(0084/0084/9999): objective =     158.57
# SGD(0085/0085/9999): objective =     157.88
# SGD(0086/0086/9999): objective =     158.36
# SGD(0087/0087/9999): objective =     151.47
# SGD(0088/0088/9999): objective =     151.42
# SGD(0089/0089/9999): objective =     145.01
# SGD(0090/0090/9999): objective =     146.14
# SGD(0091/0091/9999): objective =     147.35
# SGD(0092/0092/9999): objective =     121.49
# SGD(0093/0093/9999): objective =     124.63
# SGD(0094/0094/9999): objective =     129.27
# SGD(0095/0095/9999): objective =     129.11
# SGD(0096/0096/9999): objective =     130.17
# SGD(0097/0097/9999): objective =     123.29
# SGD(0098/0098/9999): objective =     123.04
# SGD(0099/0099/9999): objective =     116.76
# Running SGD with batch size 10...
# SGD(0000/0000/9999): objective =   28276.02
# SGD(0001/0001/9999): objective =   23965.87
# SGD(0002/0002/9999): objective =   21534.22
# SGD(0003/0003/9999): objective =   19661.22
# SGD(0004/0004/9999): objective =   17720.10
# SGD(0005/0005/9999): objective =   16633.54
# SGD(0006/0006/9999): objective =   15018.98
# SGD(0007/0007/9999): objective =   13968.77
# SGD(0008/0008/9999): objective =   13194.32
# SGD(0009/0009/9999): objective =   12672.15
# SGD(0010/0010/9999): objective =   10974.35
# SGD(0011/0011/9999): objective =   10075.41
# SGD(0012/0012/9999): objective =    9219.48
# SGD(0013/0013/9999): objective =    8194.81
# SGD(0014/0014/9999): objective =    7543.22
# SGD(0015/0015/9999): objective =    6977.04
# SGD(0016/0016/9999): objective =    5963.89
# SGD(0017/0017/9999): objective =    5580.79
# SGD(0018/0018/9999): objective =    5044.20
# SGD(0019/0019/9999): objective =    4617.45
# SGD(0020/0020/9999): objective =    4269.74
# SGD(0021/0021/9999): objective =    3739.20
# SGD(0022/0022/9999): objective =    3329.47
# SGD(0023/0023/9999): objective =    3072.96
# SGD(0024/0024/9999): objective =    2673.23
# SGD(0025/0025/9999): objective =    2587.66
# SGD(0026/0026/9999): objective =    2534.05
# SGD(0027/0027/9999): objective =    2272.22
# SGD(0028/0028/9999): objective =    2010.90
# SGD(0029/0029/9999): objective =    1792.26
# SGD(0030/0030/9999): objective =    1698.80
# SGD(0031/0031/9999): objective =    1638.17
# SGD(0032/0032/9999): objective =    1530.65
# SGD(0033/0033/9999): objective =    1419.33
# SGD(0034/0034/9999): objective =    1281.99
# SGD(0035/0035/9999): objective =    1155.44
# SGD(0036/0036/9999): objective =    1097.47
# SGD(0037/0037/9999): objective =     983.59
# SGD(0038/0038/9999): objective =     941.76
# SGD(0039/0039/9999): objective =     903.00
# SGD(0040/0040/9999): objective =     834.05
# SGD(0041/0041/9999): objective =     804.54
# SGD(0042/0042/9999): objective =     756.41
# SGD(0043/0043/9999): objective =     724.64
# SGD(0044/0044/9999): objective =     677.86
# SGD(0045/0045/9999): objective =     552.64
# SGD(0046/0046/9999): objective =     523.19
# SGD(0047/0047/9999): objective =     474.68
# SGD(0048/0048/9999): objective =     430.91
# SGD(0049/0049/9999): objective =     367.91
# SGD(0050/0050/9999): objective =     336.01
# SGD(0051/0051/9999): objective =     295.57
# SGD(0052/0052/9999): objective =     289.34
# SGD(0053/0053/9999): objective =     260.43
# SGD(0054/0054/9999): objective =     234.29
# SGD(0055/0055/9999): objective =     220.32
# SGD(0056/0056/9999): objective =     203.25
# SGD(0057/0057/9999): objective =     173.70
# SGD(0058/0058/9999): objective =     164.05
# SGD(0059/0059/9999): objective =     150.63
# SGD(0060/0060/9999): objective =     144.05
# SGD(0061/0061/9999): objective =     136.75
# SGD(0062/0062/9999): objective =     131.84
# SGD(0063/0063/9999): objective =     117.96
# SGD(0064/0064/9999): objective =     108.22
# SGD(0065/0065/9999): objective =      98.65
# SGD(0066/0066/9999): objective =      95.01
# SGD(0067/0067/9999): objective =      92.12
# SGD(0068/0068/9999): objective =      89.60
# SGD(0069/0069/9999): objective =      87.26
# SGD(0070/0070/9999): objective =      87.57
# SGD(0071/0071/9999): objective =      84.33
# SGD(0072/0072/9999): objective =      83.55
# SGD(0073/0073/9999): objective =      83.95
# SGD(0074/0074/9999): objective =      79.47
# SGD(0075/0075/9999): objective =      76.75
# SGD(0076/0076/9999): objective =      74.09
# SGD(0077/0077/9999): objective =      70.02
# SGD(0078/0078/9999): objective =      67.77
# SGD(0079/0079/9999): objective =      66.49
# SGD(0080/0080/9999): objective =      65.52
# SGD(0081/0081/9999): objective =      64.96
# SGD(0082/0082/9999): objective =      63.71
# SGD(0083/0083/9999): objective =      63.92
# SGD(0084/0084/9999): objective =      63.02
# SGD(0085/0085/9999): objective =      63.54
# SGD(0086/0086/9999): objective =      62.72
# SGD(0087/0087/9999): objective =      59.53
# SGD(0088/0088/9999): objective =      58.90
# SGD(0089/0089/9999): objective =      57.57
# SGD(0090/0090/9999): objective =      58.06
# SGD(0091/0091/9999): objective =      57.73
# SGD(0092/0092/9999): objective =      56.86
# SGD(0093/0093/9999): objective =      56.06
# SGD(0094/0094/9999): objective =      56.19
# SGD(0095/0095/9999): objective =      55.55
# SGD(0096/0096/9999): objective =      55.08
# SGD(0097/0097/9999): objective =      53.73
# SGD(0098/0098/9999): objective =      53.87
# SGD(0099/0099/9999): objective =      52.66
# Running SGD with batch size 100...
# SGD(0000/0000/9999): objective =   27790.16
# SGD(0001/0001/9999): objective =   25351.38
# SGD(0002/0002/9999): objective =   23010.42
# SGD(0003/0003/9999): objective =   20825.57
# SGD(0004/0004/9999): objective =   18969.63
# SGD(0005/0005/9999): objective =   17313.80
# SGD(0006/0006/9999): objective =   15733.35
# SGD(0007/0007/9999): objective =   14305.63
# SGD(0008/0008/9999): objective =   13105.66
# SGD(0009/0009/9999): objective =   11601.71
# SGD(0010/0010/9999): objective =   10302.28
# SGD(0011/0011/9999): objective =    9356.02
# SGD(0012/0012/9999): objective =    8347.90
# SGD(0013/0013/9999): objective =    7506.02
# SGD(0014/0014/9999): objective =    6774.29
# SGD(0015/0015/9999): objective =    6063.12
# SGD(0016/0016/9999): objective =    5353.93
# SGD(0017/0017/9999): objective =    4906.41
# SGD(0018/0018/9999): objective =    4426.77
# SGD(0019/0019/9999): objective =    4053.03
# SGD(0020/0020/9999): objective =    3630.10
# SGD(0021/0021/9999): objective =    3300.81
# SGD(0022/0022/9999): objective =    3012.77
# SGD(0023/0023/9999): objective =    2679.43
# SGD(0024/0024/9999): objective =    2418.20
# SGD(0025/0025/9999): objective =    2203.47
# SGD(0026/0026/9999): objective =    1985.18
# SGD(0027/0027/9999): objective =    1807.22
# SGD(0028/0028/9999): objective =    1599.25
# SGD(0029/0029/9999): objective =    1475.73
# SGD(0030/0030/9999): objective =    1332.35
# SGD(0031/0031/9999): objective =    1226.75
# SGD(0032/0032/9999): objective =    1110.68
# SGD(0033/0033/9999): objective =     989.73
# SGD(0034/0034/9999): objective =     890.28
# SGD(0035/0035/9999): objective =     793.34
# SGD(0036/0036/9999): objective =     729.01
# SGD(0037/0037/9999): objective =     670.32
# SGD(0038/0038/9999): objective =     610.66
# SGD(0039/0039/9999): objective =     545.59
# SGD(0040/0040/9999): objective =     493.38
# SGD(0041/0041/9999): objective =     459.62
# SGD(0042/0042/9999): objective =     426.74
# SGD(0043/0043/9999): objective =     394.44
# SGD(0044/0044/9999): objective =     354.94
# SGD(0045/0045/9999): objective =     323.89
# SGD(0046/0046/9999): objective =     299.92
# SGD(0047/0047/9999): objective =     271.98
# SGD(0048/0048/9999): objective =     257.07
# SGD(0049/0049/9999): objective =     232.98
# SGD(0050/0050/9999): objective =     218.57
# SGD(0051/0051/9999): objective =     198.32
# SGD(0052/0052/9999): objective =     185.16
# SGD(0053/0053/9999): objective =     171.98
# SGD(0054/0054/9999): objective =     158.03
# SGD(0055/0055/9999): objective =     146.41
# SGD(0056/0056/9999): objective =     137.15
# SGD(0057/0057/9999): objective =     125.47
# SGD(0058/0058/9999): objective =     118.08
# SGD(0059/0059/9999): objective =     111.49
# SGD(0060/0060/9999): objective =     104.28
# SGD(0061/0061/9999): objective =      99.52
# SGD(0062/0062/9999): objective =      93.62
# SGD(0063/0063/9999): objective =      91.43
# SGD(0064/0064/9999): objective =      87.75
# SGD(0065/0065/9999): objective =      83.79
# SGD(0066/0066/9999): objective =      80.71
# SGD(0067/0067/9999): objective =      77.30
# SGD(0068/0068/9999): objective =      74.41
# SGD(0069/0069/9999): objective =      71.51
# SGD(0070/0070/9999): objective =      69.59
# SGD(0071/0071/9999): objective =      67.66
# SGD(0072/0072/9999): objective =      66.39
# SGD(0073/0073/9999): objective =      64.48
# SGD(0074/0074/9999): objective =      62.52
# SGD(0075/0075/9999): objective =      61.72
# SGD(0076/0076/9999): objective =      60.70
# SGD(0077/0077/9999): objective =      59.79
# SGD(0078/0078/9999): objective =      58.26
# SGD(0079/0079/9999): objective =      57.39
# SGD(0080/0080/9999): objective =      56.51
# SGD(0081/0081/9999): objective =      55.88
# SGD(0082/0082/9999): objective =      54.79
# SGD(0083/0083/9999): objective =      54.10
# SGD(0084/0084/9999): objective =      53.84
# SGD(0085/0085/9999): objective =      53.15
# SGD(0086/0086/9999): objective =      52.78
# SGD(0087/0087/9999): objective =      52.56
# SGD(0088/0088/9999): objective =      52.19
# SGD(0089/0089/9999): objective =      51.98
# SGD(0090/0090/9999): objective =      51.76
# SGD(0091/0091/9999): objective =      51.49
# SGD(0092/0092/9999): objective =      51.24
# SGD(0093/0093/9999): objective =      51.16
# SGD(0094/0094/9999): objective =      51.05
# SGD(0095/0095/9999): objective =      50.81
# SGD(0096/0096/9999): objective =      50.84
# SGD(0097/0097/9999): objective =      50.70
# SGD(0098/0098/9999): objective =      50.51
# SGD(0099/0099/9999): objective =      50.56
# Running SGD with batch size 1000...
# SGD(0000/0000/9999): objective =   27025.45
# SGD(0001/0001/9999): objective =   24338.38
# SGD(0002/0002/9999): objective =   22174.36
# SGD(0003/0003/9999): objective =   20125.33
# SGD(0004/0004/9999): objective =   18257.44
# SGD(0005/0005/9999): objective =   16498.57
# SGD(0006/0006/9999): objective =   14908.93
# SGD(0007/0007/9999): objective =   13414.06
# SGD(0008/0008/9999): objective =   12104.79
# SGD(0009/0009/9999): objective =   10941.54
# SGD(0010/0010/9999): objective =    9773.09
# SGD(0011/0011/9999): objective =    8910.16
# SGD(0012/0012/9999): objective =    8052.03
# SGD(0013/0013/9999): objective =    7271.47
# SGD(0014/0014/9999): objective =    6605.54
# SGD(0015/0015/9999): objective =    5957.95
# SGD(0016/0016/9999): objective =    5320.85
# SGD(0017/0017/9999): objective =    4831.17
# SGD(0018/0018/9999): objective =    4391.92
# SGD(0019/0019/9999): objective =    3964.56
# SGD(0020/0020/9999): objective =    3606.50
# SGD(0021/0021/9999): objective =    3275.94
# SGD(0022/0022/9999): objective =    2953.60
# SGD(0023/0023/9999): objective =    2685.28
# SGD(0024/0024/9999): objective =    2430.97
# SGD(0025/0025/9999): objective =    2212.94
# SGD(0026/0026/9999): objective =    2014.51
# SGD(0027/0027/9999): objective =    1819.69
# SGD(0028/0028/9999): objective =    1650.64
# SGD(0029/0029/9999): objective =    1492.58
# SGD(0030/0030/9999): objective =    1354.07
# SGD(0031/0031/9999): objective =    1226.36
# SGD(0032/0032/9999): objective =    1124.83
# SGD(0033/0033/9999): objective =    1024.16
# SGD(0034/0034/9999): objective =     925.99
# SGD(0035/0035/9999): objective =     842.15
# SGD(0036/0036/9999): objective =     767.77
# SGD(0037/0037/9999): objective =     699.43
# SGD(0038/0038/9999): objective =     632.28
# SGD(0039/0039/9999): objective =     577.17
# SGD(0040/0040/9999): objective =     523.15
# SGD(0041/0041/9999): objective =     476.21
# SGD(0042/0042/9999): objective =     430.63
# SGD(0043/0043/9999): objective =     394.47
# SGD(0044/0044/9999): objective =     358.75
# SGD(0045/0045/9999): objective =     328.17
# SGD(0046/0046/9999): objective =     299.90
# SGD(0047/0047/9999): objective =     275.96
# SGD(0048/0048/9999): objective =     255.61
# SGD(0049/0049/9999): objective =     235.48
# SGD(0050/0050/9999): objective =     217.51
# SGD(0051/0051/9999): objective =     201.46
# SGD(0052/0052/9999): objective =     185.83
# SGD(0053/0053/9999): objective =     172.97
# SGD(0054/0054/9999): objective =     161.95
# SGD(0055/0055/9999): objective =     151.89
# SGD(0056/0056/9999): objective =     143.03
# SGD(0057/0057/9999): objective =     133.41
# SGD(0058/0058/9999): objective =     125.29
# SGD(0059/0059/9999): objective =     118.18
# SGD(0060/0060/9999): objective =     111.55
# SGD(0061/0061/9999): objective =     105.31
# SGD(0062/0062/9999): objective =      99.98
# SGD(0063/0063/9999): objective =      95.21
# SGD(0064/0064/9999): objective =      90.99
# SGD(0065/0065/9999): objective =      87.05
# SGD(0066/0066/9999): objective =      83.29
# SGD(0067/0067/9999): objective =      80.09
# SGD(0068/0068/9999): objective =      77.20
# SGD(0069/0069/9999): objective =      74.66
# SGD(0070/0070/9999): objective =      72.24
# SGD(0071/0071/9999): objective =      70.05
# SGD(0072/0072/9999): objective =      68.05
# SGD(0073/0073/9999): objective =      66.30
# SGD(0074/0074/9999): objective =      64.67
# SGD(0075/0075/9999): objective =      63.14
# SGD(0076/0076/9999): objective =      61.79
# SGD(0077/0077/9999): objective =      60.64
# SGD(0078/0078/9999): objective =      59.43
# SGD(0079/0079/9999): objective =      58.54
# SGD(0080/0080/9999): objective =      57.56
# SGD(0081/0081/9999): objective =      56.83
# SGD(0082/0082/9999): objective =      56.18
# SGD(0083/0083/9999): objective =      55.53
# SGD(0084/0084/9999): objective =      55.00
# SGD(0085/0085/9999): objective =      54.42
# SGD(0086/0086/9999): objective =      53.87
# SGD(0087/0087/9999): objective =      53.35
# SGD(0088/0088/9999): objective =      52.98
# SGD(0089/0089/9999): objective =      52.63
# SGD(0090/0090/9999): objective =      52.25
# SGD(0091/0091/9999): objective =      51.98
# SGD(0092/0092/9999): objective =      51.75
# SGD(0093/0093/9999): objective =      51.53
# SGD(0094/0094/9999): objective =      51.30
# SGD(0095/0095/9999): objective =      51.10
# SGD(0096/0096/9999): objective =      50.97
# SGD(0097/0097/9999): objective =      50.76
# SGD(0098/0098/9999): objective =      50.66
# SGD(0099/0099/9999): objective =      50.58
# Running SGD with batch size 10000...
# SGD(0000/0000/9999): objective =   27134.06
# SGD(0001/0001/9999): objective =   24497.55
# SGD(0002/0002/9999): objective =   22117.91
# SGD(0003/0003/9999): objective =   19970.10
# SGD(0004/0004/9999): objective =   18031.51
# SGD(0005/0005/9999): objective =   16281.74
# SGD(0006/0006/9999): objective =   14702.39
# SGD(0007/0007/9999): objective =   13276.85
# SGD(0008/0008/9999): objective =   11990.11
# SGD(0009/0009/9999): objective =   10828.66
# SGD(0010/0010/9999): objective =    9780.28
# SGD(0011/0011/9999): objective =    8833.96
# SGD(0012/0012/9999): objective =    7979.75
# SGD(0013/0013/9999): objective =    7208.67
# SGD(0014/0014/9999): objective =    6512.64
# SGD(0015/0015/9999): objective =    5884.34
# SGD(0016/0016/9999): objective =    5317.17
# SGD(0017/0017/9999): objective =    4805.18
# SGD(0018/0018/9999): objective =    4342.99
# SGD(0019/0019/9999): objective =    3925.77
# SGD(0020/0020/9999): objective =    3549.12
# SGD(0021/0021/9999): objective =    3209.10
# SGD(0022/0022/9999): objective =    2902.15
# SGD(0023/0023/9999): objective =    2625.05
# SGD(0024/0024/9999): objective =    2374.88
# SGD(0025/0025/9999): objective =    2149.03
# SGD(0026/0026/9999): objective =    1945.14
# SGD(0027/0027/9999): objective =    1761.07
# SGD(0028/0028/9999): objective =    1594.88
# SGD(0029/0029/9999): objective =    1444.84
# SGD(0030/0030/9999): objective =    1309.39
# SGD(0031/0031/9999): objective =    1187.09
# SGD(0032/0032/9999): objective =    1076.67
# SGD(0033/0033/9999): objective =     976.98
# SGD(0034/0034/9999): objective =     886.97
# SGD(0035/0035/9999): objective =     805.71
# SGD(0036/0036/9999): objective =     732.33
# SGD(0037/0037/9999): objective =     666.08
# SGD(0038/0038/9999): objective =     606.27
# SGD(0039/0039/9999): objective =     552.26
# SGD(0040/0040/9999): objective =     503.49
# SGD(0041/0041/9999): objective =     459.45
# SGD(0042/0042/9999): objective =     419.69
# SGD(0043/0043/9999): objective =     383.79
# SGD(0044/0044/9999): objective =     351.37
# SGD(0045/0045/9999): objective =     322.10
# SGD(0046/0046/9999): objective =     295.67
# SGD(0047/0047/9999): objective =     271.80
# SGD(0048/0048/9999): objective =     250.25
# SGD(0049/0049/9999): objective =     230.78
# SGD(0050/0050/9999): objective =     213.21
# SGD(0051/0051/9999): objective =     197.34
# SGD(0052/0052/9999): objective =     183.00
# SGD(0053/0053/9999): objective =     170.06
# SGD(0054/0054/9999): objective =     158.37
# SGD(0055/0055/9999): objective =     147.82
# SGD(0056/0056/9999): objective =     138.28
# SGD(0057/0057/9999): objective =     129.68
# SGD(0058/0058/9999): objective =     121.90
# SGD(0059/0059/9999): objective =     114.88
# SGD(0060/0060/9999): objective =     108.54
# SGD(0061/0061/9999): objective =     102.81
# SGD(0062/0062/9999): objective =      97.64
# SGD(0063/0063/9999): objective =      92.97
# SGD(0064/0064/9999): objective =      88.75
# SGD(0065/0065/9999): objective =      84.94
# SGD(0066/0066/9999): objective =      81.50
# SGD(0067/0067/9999): objective =      78.39
# SGD(0068/0068/9999): objective =      75.58
# SGD(0069/0069/9999): objective =      73.05
# SGD(0070/0070/9999): objective =      70.76
# SGD(0071/0071/9999): objective =      68.69
# SGD(0072/0072/9999): objective =      66.82
# SGD(0073/0073/9999): objective =      65.13
# SGD(0074/0074/9999): objective =      63.61
# SGD(0075/0075/9999): objective =      62.23
# SGD(0076/0076/9999): objective =      60.99
# SGD(0077/0077/9999): objective =      59.86
# SGD(0078/0078/9999): objective =      58.85
# SGD(0079/0079/9999): objective =      57.93
# SGD(0080/0080/9999): objective =      57.11
# SGD(0081/0081/9999): objective =      56.36
# SGD(0082/0082/9999): objective =      55.68
# SGD(0083/0083/9999): objective =      55.07
# SGD(0084/0084/9999): objective =      54.52
# SGD(0085/0085/9999): objective =      54.02
# SGD(0086/0086/9999): objective =      53.57
# SGD(0087/0087/9999): objective =      53.17
# SGD(0088/0088/9999): objective =      52.80
# SGD(0089/0089/9999): objective =      52.47
# SGD(0090/0090/9999): objective =      52.17
# SGD(0091/0091/9999): objective =      51.90
# SGD(0092/0092/9999): objective =      51.65
# SGD(0093/0093/9999): objective =      51.43
# SGD(0094/0094/9999): objective =      51.23
# SGD(0095/0095/9999): objective =      51.05
# SGD(0096/0096/9999): objective =      50.89
# SGD(0097/0097/9999): objective =      50.74
# SGD(0098/0098/9999): objective =      50.61
# SGD(0099/0099/9999): objective =      50.49
# SGD: execution time=0.039 seconds

# %% [markdown]
# Compare your results with the classic (full batch) gradient method.

# %% [markdown]
# The experiment demonstrates that the **batch_size = 1** curve is the most irregular: we could see plateaus and sudden drops, so the descent is quite noisy.The **mini-batch** curves (**10** and **100**) are much smoother and decrease more steadily.
# They also reach low objective values quickly, with a more regular convergence behavior.
# We could also observe that  **full-batch** curve (**1000**) is smooth as well, but here it does not look clearly faster than the mini-batch cases.
# Hence, **mini-batch gradient descent** seems to give the best trade-off between speed and stability in this experiment.

# %% [markdown]
# ## 2 - Support Vector Machine

# %% [markdown]
# In this section, we will implement a stochastic (sub)-gradient algorithm in order to solve the soft primal margin SVM training problem. Recall the problem:
# $$
# \displaystyle \min_{w,b} \frac{1}{2}\|w\|^2 + C\sum_{i=1}^{n} \max\{0,1-y_i(w^Tx_i+b)\}
# $$
# where $C$ is a parameter. In the following, we will write $\theta=(w,b)$ where $w=(\theta_1,\ldots,\theta_d)$ and $b=\theta_{d+1}$.

# %% [markdown]
# Let us first import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.utils import shuffle

# %% [markdown]
# Then define a function to generate two clusters of 2D data point that we will try to separate using the SVM. The number of points generated is a parameter of the function.

# %%
def generatedata2(n):
    # n must be an even integer
    np.random.seed(0)
    mean1, cov1, n1 = [1, 5], [[1,1],[1,2]], int(n/2)  # n/2 samples of class 1
    x1 = np.random.multivariate_normal(mean1, cov1, n1)
    y1 = np.ones(n1, dtype=int)
    mean2, cov2, n2 = [2.5, 2.5], [[1,0],[0,1]], int(n/2) # n/2 samples of class -1
    x2 = np.random.multivariate_normal(mean2, cov2, n2)
    y2 = -np.ones(n2, dtype=int)
    x = np.concatenate((x1, x2), axis=0) # concatenate the samples
    y = np.concatenate((y1, y2))
    x,y = shuffle(x,y)
    
    return [x,y]

# %% [markdown]
# Let us now define a function that will plot the data and a function to plot the hyperplane (and the supporting hyperplanes) generated by the SVM and represented in the form of $\theta=(w,b)$ (meaning $w^Tx+b=0$).

# %%
def plotdata(x,y):
    for i in range(x.shape[0]):
        if y[i]==-1:
            cl='bo';
        else:
                cl='r+';
        plt.plot(x[i,0],x[i,1],cl);
    return

def plothyperplane(w,b,x):
    xx=np.linspace(x[:,0].min(),x[:,0].max(),100);
    #print(xx)
    yy=(-b-w[0]*xx)/w[1];
    yy1=yy+1/np.linalg.norm(w);
    yy2=yy-1/np.linalg.norm(w);
    #print(yy)
    plt.plot(xx,yy,'k-')
    plt.plot(xx,yy1,'g-')
    plt.plot(xx,yy2,'g-')
    return

# %% [markdown]
# Define first the function that computes the value of the SVM problem objective function at $\theta$.

# %%
def SVMobjective(x,y,d,C,theta):
    w = theta[0:d]
    b = theta[d]
    loss = 0.5 * np.linalg.norm(w)**2
    n= len(y)
    for i in range( n):
        loss += C * max(0, 1 - y[i] * (np.dot(w, x[i]) + b))
    return loss

# %% [markdown]
# Define now a new function that will take as parameters a batch of samples $(x_i,y_i)_{i=1,\ldots,batch size}$ and return a stochastic subgradient of the objective function at $\theta$ by considering only the terms of the batch.

# %%
def minibatch_subgrad_svm(x_batch,y_batch,d,C,theta):
    w = theta[0:d] 
    b= theta[d]
    subgrad = np.concatenate((w,np.zeros(1)),axis=0)
    n= len(y_batch)
    for i in range(n):
        if  1 - y_batch[i] * (np.dot(w, x_batch[i]) + b) >= 0:
            subgrad -= C*y_batch[i] * np.concatenate((x_batch[i],np.ones(1)),axis=0)

    return subgrad

# %% [markdown]
# Use the above function to implement the following svm_SGD algorithm:

# %%
def svm_SGD(x,y,d,C,theta,batch_size,lr,nmax):
    
    thetas = [theta]
    objectives = []
    n= len(y)
    for epoch in range(nmax):
        for iter in range(int(len(y)/batch_size)):
            indices = np.random.choice(n, batch_size, replace=True)
            x_batch= x[indices,:]
            y_batch= y[indices]
            SVMgrad= minibatch_subgrad_svm(x_batch,y_batch,d,C,theta) 
        
            # update x through the gradient update
            theta -= lr* SVMgrad
                
            # store x and objective
            thetas.append(theta.copy())
            objective=SVMobjective(x,y,d,C,theta)
            objectives.append(objective)
            print("SGD({ep:04d}/{bi:04d}/{ti:04d}): objective = {l:10.2f}".format(ep=epoch,
                          bi=epoch, ti=len(y) - 1, l=objective))
    return objectives, thetas

# %%
plt.close("all");

d=2
n=1000
C=10
nmax=100
lr=0.01
batch_size=100

[x,y]=generatedata2(n);

plt.figure(0);
plotdata(x,y);
plt.title("Data points")

theta_initial=np.empty([d+1])
theta_initial[:d]=np.zeros([2]);
theta_initial[d]=0

obj=np.empty(nmax);
objectives, thetas = svm_SGD(x,y,d,C,theta_initial,batch_size,lr,nmax)
predict=np.empty(n);
w=thetas[-1][:d]
b=thetas[-1][d]

error=0;
for j in range(n):
    predict[j]=np.sign(np.dot(x[j,:],w)+b);
    if y[j]!=predict[j]:
        error+=1;
plothyperplane(w,b,x);

#error
training_error=error*100/n
print('Training error=',training_error)
# Out:
# SGD(0000/0000/0999): objective =  111215.37
# SGD(0000/0000/0999): objective =  110694.75
# SGD(0000/0000/0999): objective =  219593.93
# SGD(0000/0000/0999): objective =   19986.73
# SGD(0000/0000/0999): objective =    7916.88
# SGD(0000/0000/0999): objective =    9306.21
# SGD(0000/0000/0999): objective =    7271.56
# SGD(0000/0000/0999): objective =    8327.11
# SGD(0000/0000/0999): objective =    9379.64
# SGD(0000/0000/0999): objective =    6679.80
# SGD(0001/0001/0999): objective =    7838.65
# SGD(0001/0001/0999): objective =    7320.58
# SGD(0001/0001/0999): objective =    7637.04
# SGD(0001/0001/0999): objective =    5859.93
# SGD(0001/0001/0999): objective =    6095.07
# SGD(0001/0001/0999): objective =    5986.33
# SGD(0001/0001/0999): objective =    5592.24
# SGD(0001/0001/0999): objective =    8671.37
# SGD(0001/0001/0999): objective =   18800.66
# SGD(0008/0008/0999): objective =   13536.20
# SGD(0008/0008/0999): objective =    4683.20
# SGD(0008/0008/0999): objective =    6593.63
# SGD(0008/0008/0999): objective =    4401.06
# SGD(0009/0009/0999): objective =    4348.61
# SGD(0009/0009/0999): objective =    5456.98
# SGD(0009/0009/0999): objective =    9944.05
# SGD(0009/0009/0999): objective =    4289.39
# SGD(0009/0009/0999): objective =    4154.85
# SGD(0009/0009/0999): objective =    4041.02
# SGD(0009/0009/0999): objective =    7205.38
# SGD(0009/0009/0999): objective =    4926.23
# SGD(0009/0009/0999): objective =    3572.00
# SGD(0009/0009/0999): objective =    3653.80
# SGD(0010/0010/0999): objective =    7568.70
# SGD(0010/0010/0999): objective =    6904.96
# SGD(0010/0010/0999): objective =   27705.24
# SGD(0010/0010/0999): objective =   49324.55
# SGD(0010/0010/0999): objective =  143112.97
# SGD(0010/0010/0999): objective =    9402.72
# SGD(0010/0010/0999): objective =    8027.00
# SGD(0010/0010/0999): objective =    5735.95
# SGD(0010/0010/0999): objective =    8927.75
# SGD(0010/0010/0999): objective =    8583.14
# SGD(0011/0011/0999): objective =    5071.56
# SGD(0011/0011/0999): objective =    5615.65
# SGD(0011/0011/0999): objective =    6202.95
# SGD(0011/0011/0999): objective =    4889.06
# SGD(0011/0011/0999): objective =    4892.94
# SGD(0011/0011/0999): objective =    4776.67
# SGD(0011/0011/0999): objective =    5274.04
# SGD(0011/0011/0999): objective =    4497.95
# SGD(0011/0011/0999): objective =    4378.49
# SGD(0011/0011/0999): objective =    5907.54
# SGD(0012/0012/0999): objective =    4532.74
# SGD(0012/0012/0999): objective =    4735.51
# SGD(0012/0012/0999): objective =    4191.33
# SGD(0012/0012/0999): objective =    4013.84
# SGD(0012/0012/0999): objective =    4585.96
# SGD(0012/0012/0999): objective =    4137.64
# SGD(0012/0012/0999): objective =    3913.10
# SGD(0012/0012/0999): objective =    5390.37
# SGD(0012/0012/0999): objective =    4277.63
# SGD(0012/0012/0999): objective =    3711.35
# SGD(0013/0013/0999): objective =    3646.59
# SGD(0013/0013/0999): objective =    4311.32
# SGD(0013/0013/0999): objective =    5005.01
# SGD(0013/0013/0999): objective =    4722.16
# SGD(0013/0013/0999): objective =    7831.54
# SGD(0013/0013/0999): objective =   34526.63
# SGD(0013/0013/0999): objective =   40978.91
# SGD(0013/0013/0999): objective =  150727.72
# SGD(0013/0013/0999): objective =    6930.00
# SGD(0013/0013/0999): objective =    6359.66
# SGD(0014/0014/0999): objective =    7935.94
# SGD(0014/0014/0999): objective =    6152.58
# SGD(0014/0014/0999): objective =    5528.78
# SGD(0014/0014/0999): objective =    5639.88
# SGD(0014/0014/0999): objective =    6256.69
# SGD(0014/0014/0999): objective =    5208.99
# SGD(0014/0014/0999): objective =    5328.29
# SGD(0014/0014/0999): objective =    5142.96
# SGD(0014/0014/0999): objective =    5321.62
# SGD(0014/0014/0999): objective =    6111.55
# SGD(0015/0015/0999): objective =    5307.57
# SGD(0015/0015/0999): objective =    6208.15
# SGD(0015/0015/0999): objective =    4689.71
# SGD(0015/0015/0999): objective =    5011.50
# SGD(0015/0015/0999): objective =    4551.43
# SGD(0015/0015/0999): objective =    5414.13
# SGD(0015/0015/0999): objective =    5242.59
# SGD(0015/0015/0999): objective =    5780.77
# SGD(0015/0015/0999): objective =   10924.23
# SGD(0015/0015/0999): objective =    4348.18
# SGD(0016/0016/0999): objective =    4355.71
# SGD(0016/0016/0999): objective =    4354.99
# SGD(0016/0016/0999): objective =    4028.21
# SGD(0016/0016/0999): objective =    5026.76
# SGD(0016/0016/0999): objective =    3974.87
# SGD(0016/0016/0999): objective =    3954.76
# SGD(0016/0016/0999): objective =    4234.60
# SGD(0016/0016/0999): objective =    4903.49
# SGD(0016/0016/0999): objective =    4183.90
# SGD(0016/0016/0999): objective =    4403.23
# SGD(0017/0017/0999): objective =    4508.09
# SGD(0017/0017/0999): objective =   10350.66
# SGD(0017/0017/0999): objective =    4950.78
# SGD(0017/0017/0999): objective =    3847.90
# SGD(0017/0017/0999): objective =    3671.71
# SGD(0017/0017/0999): objective =    4193.56
# SGD(0017/0017/0999): objective =    4082.93
# SGD(0017/0017/0999): objective =    4330.57
# SGD(0017/0017/0999): objective =    4116.53
# SGD(0017/0017/0999): objective =    3464.11
# SGD(0018/0018/0999): objective =    3501.17
# SGD(0018/0018/0999): objective =    3736.61
# SGD(0018/0018/0999): objective =    3607.46
# SGD(0018/0018/0999): objective =    8697.62
# SGD(0018/0018/0999): objective =    4593.40
# SGD(0018/0018/0999): objective =    4743.17
# SGD(0018/0018/0999): objective =   24531.31
# SGD(0018/0018/0999): objective =  198019.99
# SGD(0018/0018/0999): objective =    5879.32
# SGD(0018/0018/0999): objective =    4605.19
# SGD(0019/0019/0999): objective =    4636.98
# SGD(0019/0019/0999): objective =    4415.41
# SGD(0019/0019/0999): objective =    4567.74
# SGD(0019/0019/0999): objective =    4266.74
# SGD(0019/0019/0999): objective =    4499.26
# SGD(0019/0019/0999): objective =    6145.69
# SGD(0019/0019/0999): objective =    4687.86
# SGD(0019/0019/0999): objective =    4212.33
# SGD(0019/0019/0999): objective =    4165.45
# SGD(0019/0019/0999): objective =    3999.53
# SGD(0020/0020/0999): objective =    4750.76
# SGD(0020/0020/0999): objective =    3832.39
# SGD(0020/0020/0999): objective =    4599.53
# SGD(0020/0020/0999): objective =    9795.03
# SGD(0020/0020/0999): objective =    4116.76
# SGD(0020/0020/0999): objective =    7046.26
# SGD(0020/0020/0999): objective =   20127.07
# SGD(0020/0020/0999): objective =    3800.39
# SGD(0020/0020/0999): objective =    3709.64
# SGD(0020/0020/0999): objective =    3634.26
# SGD(0021/0021/0999): objective =    4121.28
# SGD(0021/0021/0999): objective =    4362.37
# SGD(0021/0021/0999): objective =    4070.86
# SGD(0021/0021/0999): objective =    3970.06
# SGD(0021/0021/0999): objective =    5713.90
# SGD(0021/0021/0999): objective =    4177.99
# SGD(0021/0021/0999): objective =    3544.64
# SGD(0021/0021/0999): objective =   10564.04
# SGD(0021/0021/0999): objective =    7936.68
# SGD(0021/0021/0999): objective =   38724.76
# SGD(0022/0022/0999): objective =   11240.61
# SGD(0035/0035/0999): objective =    6261.85
# SGD(0035/0035/0999): objective =    4621.16
# SGD(0035/0035/0999): objective =    5184.38
# SGD(0035/0035/0999): objective =    6813.71
# SGD(0035/0035/0999): objective =    5810.44
# SGD(0036/0036/0999): objective =    5256.51
# SGD(0036/0036/0999): objective =    4632.05
# SGD(0036/0036/0999): objective =    4247.87
# SGD(0036/0036/0999): objective =    4466.70
# SGD(0036/0036/0999): objective =    4150.87
# SGD(0036/0036/0999): objective =    4082.22
# SGD(0036/0036/0999): objective =    4844.78
# SGD(0036/0036/0999): objective =    5070.16
# SGD(0036/0036/0999): objective =    8806.26
# SGD(0036/0036/0999): objective =   12753.08
# SGD(0037/0037/0999): objective =    4055.79
# SGD(0037/0037/0999): objective =    4089.09
# SGD(0037/0037/0999): objective =    4560.65
# SGD(0037/0037/0999): objective =    6100.27
# SGD(0037/0037/0999): objective =    5869.27
# SGD(0037/0037/0999): objective =    4105.43
# SGD(0037/0037/0999): objective =    5518.48
# SGD(0037/0037/0999): objective =    4112.97
# SGD(0037/0037/0999): objective =    6476.49
# SGD(0037/0037/0999): objective =    5829.27
# SGD(0038/0038/0999): objective =    3662.22
# SGD(0038/0038/0999): objective =    5283.34
# SGD(0038/0038/0999): objective =    4613.94
# SGD(0038/0038/0999): objective =    8584.93
# SGD(0038/0038/0999): objective =   19905.25
# SGD(0038/0038/0999): objective =  114090.87
# SGD(0038/0038/0999): objective =    5093.46
# SGD(0038/0038/0999): objective =    5084.18
# SGD(0038/0038/0999): objective =    4587.11
# SGD(0038/0038/0999): objective =    4891.40
# SGD(0039/0039/0999): objective =    4559.86
# SGD(0039/0039/0999): objective =    9843.72
# SGD(0039/0039/0999): objective =    5507.67
# SGD(0039/0039/0999): objective =    4981.46
# SGD(0039/0039/0999): objective =    4422.92
# SGD(0039/0039/0999): objective =    4830.32
# SGD(0039/0039/0999): objective =    5117.66
# SGD(0039/0039/0999): objective =    4169.06
# SGD(0039/0039/0999): objective =    4148.24
# SGD(0039/0039/0999): objective =    4250.74
# SGD(0040/0040/0999): objective =    4258.54
# SGD(0040/0040/0999): objective =    4146.23
# SGD(0040/0040/0999): objective =    3841.71
# SGD(0040/0040/0999): objective =    3808.63
# SGD(0040/0040/0999): objective =    4872.20
# SGD(0040/0040/0999): objective =    5417.91
# SGD(0040/0040/0999): objective =    6036.55
# SGD(0040/0040/0999): objective =    4446.53
# SGD(0040/0040/0999): objective =    3888.91
# SGD(0040/0040/0999): objective =    7380.65
# SGD(0041/0041/0999): objective =    7091.73
# SGD(0041/0041/0999): objective =    4123.25
# SGD(0041/0041/0999): objective =    4843.71
# SGD(0041/0041/0999): objective =    3980.47
# SGD(0041/0041/0999): objective =    4962.38
# SGD(0041/0041/0999): objective =   10082.69
# SGD(0041/0041/0999): objective =    3665.12
# SGD(0041/0041/0999): objective =    5108.61
# SGD(0041/0041/0999): objective =    6989.31
# SGD(0041/0041/0999): objective =   11891.66
# SGD(0042/0042/0999): objective =   43683.86
# SGD(0042/0042/0999): objective =    6455.48
# SGD(0055/0055/0999): objective =    3814.58
# SGD(0055/0055/0999): objective =    4519.89
# SGD(0055/0055/0999): objective =    6788.54
# SGD(0056/0056/0999): objective =    4925.91
# SGD(0056/0056/0999): objective =    7256.11
# SGD(0056/0056/0999): objective =   18189.63
# SGD(0056/0056/0999): objective =   57786.46
# SGD(0056/0056/0999): objective =   61926.38
# SGD(0056/0056/0999): objective =   76898.09
# SGD(0056/0056/0999): objective =    7376.87
# SGD(0056/0056/0999): objective =    5366.05
# SGD(0056/0056/0999): objective =    5438.01
# SGD(0056/0056/0999): objective =    6197.62
# SGD(0057/0057/0999): objective =    5727.60
# SGD(0057/0057/0999): objective =    4964.84
# SGD(0057/0057/0999): objective =    5259.87
# SGD(0057/0057/0999): objective =    4661.29
# SGD(0057/0057/0999): objective =    4697.79
# SGD(0057/0057/0999): objective =    6145.86
# SGD(0057/0057/0999): objective =   15761.51
# SGD(0057/0057/0999): objective =    6014.34
# SGD(0057/0057/0999): objective =    4497.51
# SGD(0057/0057/0999): objective =    5363.90
# SGD(0058/0058/0999): objective =    9047.00
# SGD(0058/0058/0999): objective =    4727.08
# SGD(0058/0058/0999): objective =    4732.04
# SGD(0058/0058/0999): objective =    4652.72
# SGD(0058/0058/0999): objective =    4381.17
# SGD(0058/0058/0999): objective =   10859.95
# SGD(0058/0058/0999): objective =    5530.40
# SGD(0058/0058/0999): objective =    4404.85
# SGD(0058/0058/0999): objective =    6374.39
# SGD(0058/0058/0999): objective =    5264.07
# SGD(0059/0059/0999): objective =    4247.90
# SGD(0059/0059/0999): objective =    3849.85
# SGD(0059/0059/0999): objective =    3780.11
# SGD(0059/0059/0999): objective =    4598.58
# SGD(0059/0059/0999): objective =    4704.00
# SGD(0059/0059/0999): objective =    3994.75
# SGD(0059/0059/0999): objective =    3680.72
# SGD(0059/0059/0999): objective =    3728.67
# SGD(0059/0059/0999): objective =    7714.42
# SGD(0059/0059/0999): objective =    5732.38
# SGD(0060/0060/0999): objective =   20759.01
# SGD(0060/0060/0999): objective =  119822.76
# SGD(0060/0060/0999): objective =   12447.39
# SGD(0060/0060/0999): objective =    7244.62
# SGD(0060/0060/0999): objective =    4576.18
# SGD(0060/0060/0999): objective =    4809.71
# SGD(0060/0060/0999): objective =    4449.78
# SGD(0060/0060/0999): objective =    4919.22
# SGD(0060/0060/0999): objective =    4608.13
# SGD(0060/0060/0999): objective =    4418.72
# SGD(0061/0061/0999): objective =    4597.67
# SGD(0061/0061/0999): objective =    4293.89
# SGD(0061/0061/0999): objective =    4194.32
# SGD(0061/0061/0999): objective =    4627.44
# SGD(0061/0061/0999): objective =    4512.06
# SGD(0061/0061/0999): objective =    4122.34
# SGD(0061/0061/0999): objective =    4185.24
# SGD(0061/0061/0999): objective =   11056.51
# SGD(0061/0061/0999): objective =    4308.26
# SGD(0061/0061/0999): objective =    6035.07
# SGD(0062/0062/0999): objective =    3888.88
# SGD(0062/0062/0999): objective =    5707.29
# SGD(0062/0062/0999): objective =   15506.35
# SGD(0062/0062/0999): objective =    6868.45
# SGD(0062/0062/0999): objective =   13554.38
# SGD(0062/0062/0999): objective =    6530.44
# SGD(0062/0062/0999): objective =   23878.93
# SGD(0062/0062/0999): objective =    4463.84
# SGD(0062/0062/0999): objective =    3918.72
# SGD(0062/0062/0999): objective =    4262.40
# SGD(0063/0063/0999): objective =    4202.07
# SGD(0063/0063/0999): objective =    4562.52
# SGD(0063/0063/0999): objective =    4573.15
# SGD(0063/0063/0999): objective =    5206.73
# SGD(0063/0063/0999): objective =   16232.18
# SGD(0063/0063/0999): objective =    3976.54
# SGD(0063/0063/0999): objective =    4434.33
# SGD(0063/0063/0999): objective =    3862.80
# SGD(0063/0063/0999): objective =    3728.56
# SGD(0063/0063/0999): objective =    3758.62
# SGD(0064/0064/0999): objective =    4285.98
# SGD(0064/0064/0999): objective =    3752.43
# SGD(0064/0064/0999): objective =    5622.01
# SGD(0064/0064/0999): objective =    6665.89
# SGD(0064/0064/0999): objective =   37933.15
# SGD(0064/0064/0999): objective =    4440.35
# SGD(0064/0064/0999): objective =    4651.58
# SGD(0064/0064/0999): objective =    3890.17
# SGD(0064/0064/0999): objective =    3981.48
# SGD(0064/0064/0999): objective =    4147.74
# SGD(0065/0065/0999): objective =    4846.73
# SGD(0065/0065/0999): objective =    3839.98
# SGD(0065/0065/0999): objective =    5465.97
# SGD(0065/0065/0999): objective =    4802.14
# SGD(0065/0065/0999): objective =    6056.34
# SGD(0065/0065/0999): objective =    3649.06
# SGD(0065/0065/0999): objective =    3633.64
# SGD(0065/0065/0999): objective =    7200.45
# SGD(0065/0065/0999): objective =    6679.20
# SGD(0065/0065/0999): objective =    3576.44
# SGD(0066/0066/0999): objective =    6340.03
# SGD(0066/0066/0999): objective =   14452.09
# SGD(0066/0066/0999): objective =    3920.96
# SGD(0066/0066/0999): objective =    3596.98
# SGD(0066/0066/0999): objective =    3847.73
# SGD(0066/0066/0999): objective =    3944.57
# SGD(0066/0066/0999): objective =    3668.73
# SGD(0066/0066/0999): objective =    3516.02
# SGD(0066/0066/0999): objective =    3559.05
# SGD(0066/0066/0999): objective =    4129.70
# SGD(0067/0067/0999): objective =    3548.19
# SGD(0067/0067/0999): objective =    3568.81
# SGD(0067/0067/0999): objective =    3683.47
# SGD(0067/0067/0999): objective =    4965.40
# SGD(0067/0067/0999): objective =    8743.20
# SGD(0067/0067/0999): objective =    9473.57
# SGD(0067/0067/0999): objective =   45815.04
# SGD(0067/0067/0999): objective =   17302.67
# SGD(0067/0067/0999): objective =   35291.89
# SGD(0067/0067/0999): objective =   10547.40
# SGD(0068/0068/0999): objective =   12039.35
# SGD(0068/0068/0999): objective =    4249.96
# SGD(0068/0068/0999): objective =   10350.29
# SGD(0068/0068/0999): objective =    6312.81
# SGD(0068/0068/0999): objective =    9098.38
# SGD(0068/0068/0999): objective =    6371.72
# SGD(0068/0068/0999): objective =    4566.85
# SGD(0068/0068/0999): objective =    4608.53
# SGD(0068/0068/0999): objective =    3843.94
# SGD(0068/0068/0999): objective =    3783.72
# SGD(0069/0069/0999): objective =    3949.54
# SGD(0069/0069/0999): objective =    4266.23
# SGD(0082/0082/0999): objective =    5983.72
# SGD(0082/0082/0999): objective =   10165.39
# SGD(0082/0082/0999): objective =    8973.91
# SGD(0082/0082/0999): objective =    7710.56
# SGD(0083/0083/0999): objective =   11018.42
# SGD(0083/0083/0999): objective =   16847.82
# SGD(0083/0083/0999): objective =    3991.82
# SGD(0083/0083/0999): objective =    4098.63
# SGD(0083/0083/0999): objective =    5712.11
# SGD(0083/0083/0999): objective =    3976.40
# SGD(0083/0083/0999): objective =    3755.71
# SGD(0083/0083/0999): objective =    3875.72
# SGD(0083/0083/0999): objective =    4450.74
# SGD(0083/0083/0999): objective =    3647.84
# SGD(0084/0084/0999): objective =    4014.64
# SGD(0084/0084/0999): objective =    3631.12
# SGD(0084/0084/0999): objective =    3579.80
# SGD(0084/0084/0999): objective =    6159.24
# SGD(0084/0084/0999): objective =    5182.43
# SGD(0084/0084/0999): objective =    3500.30
# SGD(0084/0084/0999): objective =    3478.52
# SGD(0084/0084/0999): objective =    3639.02
# SGD(0084/0084/0999): objective =    3497.24
# SGD(0084/0084/0999): objective =    4803.05
# SGD(0085/0085/0999): objective =    6477.86
# SGD(0085/0085/0999): objective =    8746.79
# SGD(0085/0085/0999): objective =   20602.87
# SGD(0085/0085/0999): objective =   65918.05
# SGD(0085/0085/0999): objective =  238092.02
# SGD(0085/0085/0999): objective =    9852.59
# SGD(0085/0085/0999): objective =    5956.37
# SGD(0085/0085/0999): objective =    5843.53
# SGD(0085/0085/0999): objective =    5498.65
# SGD(0085/0085/0999): objective =    5614.68
# SGD(0086/0086/0999): objective =    6350.90
# SGD(0086/0086/0999): objective =    5423.35
# SGD(0086/0086/0999): objective =    5730.54
# SGD(0086/0086/0999): objective =    5035.38
# SGD(0086/0086/0999): objective =    4882.05
# SGD(0086/0086/0999): objective =    5936.82
# SGD(0086/0086/0999): objective =    5545.80
# SGD(0086/0086/0999): objective =    5087.60
# SGD(0086/0086/0999): objective =    4754.90
# SGD(0086/0086/0999): objective =    4486.85
# SGD(0087/0087/0999): objective =    5419.93
# SGD(0087/0087/0999): objective =    7449.58
# SGD(0087/0087/0999): objective =    8811.30
# SGD(0087/0087/0999): objective =    4498.06
# SGD(0087/0087/0999): objective =    6460.97
# SGD(0087/0087/0999): objective =    4625.35
# SGD(0087/0087/0999): objective =    4176.82
# SGD(0087/0087/0999): objective =    4414.51
# SGD(0087/0087/0999): objective =    3989.21
# SGD(0087/0087/0999): objective =    5294.12
# SGD(0088/0088/0999): objective =    5639.26
# SGD(0088/0088/0999): objective =    3899.14
# SGD(0088/0088/0999): objective =    5961.23
# SGD(0088/0088/0999): objective =    3916.41
# SGD(0088/0088/0999): objective =    3966.87
# SGD(0088/0088/0999): objective =    3705.46
# SGD(0088/0088/0999): objective =    3788.22
# SGD(0088/0088/0999): objective =    5924.98
# SGD(0088/0088/0999): objective =    3641.05
# SGD(0088/0088/0999): objective =    3732.99
# SGD(0089/0089/0999): objective =    5439.45
# SGD(0089/0089/0999): objective =    8446.65
# SGD(0089/0089/0999): objective =   20318.80
# SGD(0089/0089/0999): objective =   82163.66
# SGD(0089/0089/0999): objective =   43037.51
# SGD(0089/0089/0999): objective =   83060.33
# SGD(0089/0089/0999): objective =    8954.68
# SGD(0089/0089/0999): objective =    6079.70
# SGD(0089/0089/0999): objective =    6022.56
# SGD(0089/0089/0999): objective =    5866.56
# SGD(0090/0090/0999): objective =    5740.85
# SGD(0090/0090/0999): objective =    5653.90
# SGD(0090/0090/0999): objective =    5554.41
# SGD(0090/0090/0999): objective =    5466.11
# SGD(0090/0090/0999): objective =    5902.01
# SGD(0090/0090/0999): objective =    5561.75
# SGD(0090/0090/0999): objective =    5212.58
# SGD(0090/0090/0999): objective =    5081.22
# SGD(0090/0090/0999): objective =    6219.64
# SGD(0090/0090/0999): objective =    6413.92
# SGD(0091/0091/0999): objective =    4841.61
# SGD(0091/0091/0999): objective =   13346.37
# SGD(0091/0091/0999): objective =    9640.95
# SGD(0091/0091/0999): objective =    4610.48
# SGD(0091/0091/0999): objective =    4543.98
# SGD(0091/0091/0999): objective =    6314.58
# SGD(0091/0091/0999): objective =    4517.79
# SGD(0091/0091/0999): objective =    5394.72
# SGD(0091/0091/0999): objective =    4319.93
# SGD(0091/0091/0999): objective =    4281.20
# SGD(0092/0092/0999): objective =    4109.34
# SGD(0092/0092/0999): objective =    6906.52
# SGD(0092/0092/0999): objective =    5257.07
# SGD(0092/0092/0999): objective =    4142.56
# SGD(0092/0092/0999): objective =    8072.50
# SGD(0092/0092/0999): objective =    9343.94
# SGD(0092/0092/0999): objective =   10834.63
# SGD(0092/0092/0999): objective =   15997.70
# SGD(0092/0092/0999): objective =   51507.88
# SGD(0092/0092/0999): objective =    6129.56
# SGD(0093/0093/0999): objective =    4811.32
# SGD(0093/0093/0999): objective =    4879.77
# SGD(0093/0093/0999): objective =    4428.00
# SGD(0093/0093/0999): objective =    4864.73
# SGD(0093/0093/0999): objective =    4371.23
# SGD(0093/0093/0999): objective =    4664.56
# SGD(0093/0093/0999): objective =    6374.87
# SGD(0093/0093/0999): objective =    7406.03
# SGD(0093/0093/0999): objective =    4328.77
# SGD(0093/0093/0999): objective =    4355.76
# SGD(0094/0094/0999): objective =    4155.93
# SGD(0094/0094/0999): objective =    4321.33
# SGD(0094/0094/0999): objective =    4348.50
# SGD(0094/0094/0999): objective =    3986.19
# SGD(0094/0094/0999): objective =    5147.16
# SGD(0094/0094/0999): objective =    3967.26
# SGD(0094/0094/0999): objective =    3899.35
# SGD(0094/0094/0999): objective =    3913.44
# SGD(0094/0094/0999): objective =    4171.25
# SGD(0094/0094/0999): objective =    6912.15
# SGD(0095/0095/0999): objective =   13248.82
# SGD(0095/0095/0999): objective =    4640.76
# SGD(0095/0095/0999): objective =    5625.33
# SGD(0095/0095/0999): objective =    4327.22
# SGD(0095/0095/0999): objective =    4591.51
# SGD(0095/0095/0999): objective =    3905.82
# SGD(0095/0095/0999): objective =    4417.17
# SGD(0095/0095/0999): objective =    5811.21
# SGD(0095/0095/0999): objective =    3634.67
# SGD(0095/0095/0999): objective =    5525.17
# SGD(0096/0096/0999): objective =   11742.50
# SGD(0096/0096/0999): objective =    5115.67
# SGD(0096/0096/0999): objective =    5122.05
# SGD(0096/0096/0999): objective =    5131.79
# SGD(0096/0096/0999): objective =    4599.73
# SGD(0096/0096/0999): objective =    3577.99
# SGD(0096/0096/0999): objective =    4725.96
# SGD(0096/0096/0999): objective =    3636.76
# SGD(0096/0096/0999): objective =    3897.81
# SGD(0096/0096/0999): objective =    3707.21
# SGD(0097/0097/0999): objective =    3457.64
# SGD(0097/0097/0999): objective =    6174.59
# SGD(0097/0097/0999): objective =   10350.72
# SGD(0097/0097/0999): objective =    5106.55
# SGD(0097/0097/0999): objective =   16556.14
# SGD(0097/0097/0999): objective =    3490.35
# SGD(0097/0097/0999): objective =    5119.15
# SGD(0097/0097/0999): objective =    4387.95
# SGD(0097/0097/0999): objective =    3448.29
# SGD(0097/0097/0999): objective =    3508.19
# SGD(0098/0098/0999): objective =    3416.14
# SGD(0098/0098/0999): objective =    3436.85
# SGD(0098/0098/0999): objective =    3622.30
# SGD(0098/0098/0999): objective =    3397.82
# SGD(0098/0098/0999): objective =    3377.15
# SGD(0098/0098/0999): objective =    3999.32
# SGD(0098/0098/0999): objective =    4336.97
# SGD(0098/0098/0999): objective =    3670.03
# SGD(0098/0098/0999): objective =    6339.48
# SGD(0098/0098/0999): objective =    3586.38
# SGD(0099/0099/0999): objective =    3529.86
# SGD(0099/0099/0999): objective =    3241.25
# SGD(0099/0099/0999): objective =    7936.97
# SGD(0099/0099/0999): objective =   30111.72
# SGD(0099/0099/0999): objective =   46408.44
# SGD(0099/0099/0999): objective =  239260.32
# SGD(0099/0099/0999): objective =   17910.09
# SGD(0099/0099/0999): objective =   11294.85
# SGD(0099/0099/0999): objective =    5998.37
# SGD(0099/0099/0999): objective =    5497.72
# Training error= 5.7

# %%
plt.figure(1);
plt.plot(range(len(objectives)),objectives)
plt.xlabel("Iteration")
plt.ylabel("Objective Value")
plt.title("Objective Value for SVM")
# Out:
# Text(0.5, 1.0, 'Objective Value for SVM')

# %%
C_vector=[0.01,0.1,1,10,100]
training_errors=[]
objectives_list = []
for C in C_vector:
    objectives, thetas = svm_SGD(x,y,d,C,theta_initial,batch_size,lr,nmax)
    objectives_list.append(objectives)
    w=thetas[-1][:d]
    b=thetas[-1][d]
    error=0;
    predict=np.zeros(n)
    for j in range(n):
        predict[j]=np.sign(np.dot(x[j,:],w)+b);
        if y[j]!=predict[j]:
            error+=1;
    training_error=error*100/n
    training_errors.append(training_error)
    print(f"C={C}: Training error={training_error}%")
# Out:
# SGD(0000/0000/0999): objective =     254.89
# SGD(0000/0000/0999): objective =     249.89
# SGD(0000/0000/0999): objective =     244.99
# SGD(0000/0000/0999): objective =     240.19
# SGD(0000/0000/0999): objective =     235.50
# SGD(0000/0000/0999): objective =     230.89
# SGD(0000/0000/0999): objective =     226.38
# SGD(0000/0000/0999): objective =     221.98
# SGD(0000/0000/0999): objective =     217.65
# SGD(0000/0000/0999): objective =     213.43
# SGD(0001/0001/0999): objective =     209.30
# SGD(0001/0001/0999): objective =     205.26
# SGD(0001/0001/0999): objective =     201.31
# SGD(0001/0001/0999): objective =     197.45
# SGD(0001/0001/0999): objective =     193.66
# SGD(0001/0001/0999): objective =     189.96
# SGD(0001/0001/0999): objective =     186.34
# SGD(0001/0001/0999): objective =     182.79
# SGD(0001/0001/0999): objective =     179.31
# SGD(0001/0001/0999): objective =     175.92
# SGD(0002/0002/0999): objective =     172.61
# SGD(0002/0002/0999): objective =     169.37
# SGD(0002/0002/0999): objective =     166.21
# SGD(0002/0002/0999): objective =     163.11
# SGD(0002/0002/0999): objective =     160.08
# SGD(0002/0002/0999): objective =     157.12
# SGD(0002/0002/0999): objective =     154.22
# SGD(0002/0002/0999): objective =     151.39
# SGD(0002/0002/0999): objective =     148.61
# SGD(0002/0002/0999): objective =     145.89
# SGD(0003/0003/0999): objective =     143.24
# SGD(0003/0003/0999): objective =     140.64
# SGD(0003/0003/0999): objective =     138.11
# SGD(0003/0003/0999): objective =     135.63
# SGD(0003/0003/0999): objective =     133.21
# SGD(0003/0003/0999): objective =     130.84
# SGD(0003/0003/0999): objective =     128.54
# SGD(0003/0003/0999): objective =     126.28
# SGD(0003/0003/0999): objective =     124.09
# SGD(0003/0003/0999): objective =     121.95
# SGD(0004/0004/0999): objective =     119.86
# SGD(0004/0004/0999): objective =     117.82
# SGD(0004/0004/0999): objective =     115.84
# SGD(0004/0004/0999): objective =     113.88
# SGD(0004/0004/0999): objective =     112.00
# SGD(0004/0004/0999): objective =     110.16
# SGD(0004/0004/0999): objective =     108.34
# SGD(0004/0004/0999): objective =     106.57
# SGD(0004/0004/0999): objective =     104.86
# SGD(0004/0004/0999): objective =     103.18
# SGD(0005/0005/0999): objective =     101.53
# SGD(0005/0005/0999): objective =      99.94
# SGD(0005/0005/0999): objective =      98.40
# SGD(0005/0005/0999): objective =      96.88
# SGD(0005/0005/0999): objective =      95.43
# SGD(0005/0005/0999): objective =      94.04
# SGD(0005/0005/0999): objective =      92.66
# SGD(0005/0005/0999): objective =      91.33
# SGD(0005/0005/0999): objective =      90.04
# SGD(0005/0005/0999): objective =      88.81
# SGD(0006/0006/0999): objective =      87.61
# SGD(0006/0006/0999): objective =      86.45
# SGD(0006/0006/0999): objective =      85.33
# SGD(0006/0006/0999): objective =      84.20
# SGD(0006/0006/0999): objective =      83.13
# SGD(0006/0006/0999): objective =      82.10
# SGD(0006/0006/0999): objective =      81.07
# SGD(0006/0006/0999): objective =      80.08
# SGD(0006/0006/0999): objective =      79.16
# SGD(0006/0006/0999): objective =      78.23
# SGD(0007/0007/0999): objective =      77.33
# SGD(0007/0007/0999): objective =      76.46
# SGD(0007/0007/0999): objective =      75.62
# SGD(0007/0007/0999): objective =      74.84
# SGD(0007/0007/0999): objective =      74.07
# SGD(0007/0007/0999): objective =      73.34
# SGD(0007/0007/0999): objective =      72.63
# SGD(0007/0007/0999): objective =      71.92
# SGD(0007/0007/0999): objective =      71.20
# SGD(0007/0007/0999): objective =      70.51
# SGD(0008/0008/0999): objective =      69.78
# SGD(0008/0008/0999): objective =      69.16
# SGD(0008/0008/0999): objective =      68.55
# SGD(0008/0008/0999): objective =      68.00
# SGD(0008/0008/0999): objective =      67.40
# SGD(0008/0008/0999): objective =      66.80
# SGD(0008/0008/0999): objective =      66.28
# SGD(0008/0008/0999): objective =      65.74
# SGD(0008/0008/0999): objective =      65.26
# SGD(0008/0008/0999): objective =      64.79
# SGD(0009/0009/0999): objective =      64.27
# SGD(0009/0009/0999): objective =      63.85
# SGD(0009/0009/0999): objective =      63.37
# SGD(0009/0009/0999): objective =      62.99
# SGD(0009/0009/0999): objective =      62.55
# SGD(0009/0009/0999): objective =      62.12
# SGD(0009/0009/0999): objective =      61.75
# SGD(0009/0009/0999): objective =      61.41
# SGD(0009/0009/0999): objective =      61.05
# SGD(0009/0009/0999): objective =      60.61
# SGD(0010/0010/0999): objective =      60.28
# SGD(0010/0010/0999): objective =      59.97
# SGD(0010/0010/0999): objective =      59.70
# SGD(0010/0010/0999): objective =      59.32
# SGD(0010/0010/0999): objective =      59.05
# SGD(0010/0010/0999): objective =      58.75
# SGD(0010/0010/0999): objective =      58.45
# SGD(0010/0010/0999): objective =      58.19
# SGD(0010/0010/0999): objective =      57.97
# SGD(0010/0010/0999): objective =      57.80
# SGD(0011/0011/0999): objective =      57.58
# SGD(0011/0011/0999): objective =      57.39
# SGD(0011/0011/0999): objective =      57.12
# SGD(0011/0011/0999): objective =      56.96
# SGD(0011/0011/0999): objective =      56.74
# SGD(0011/0011/0999): objective =      56.60
# SGD(0011/0011/0999): objective =      56.44
# SGD(0011/0011/0999): objective =      56.37
# SGD(0011/0011/0999): objective =      56.18
# SGD(0011/0011/0999): objective =      56.07
# SGD(0012/0012/0999): objective =      55.97
# SGD(0012/0012/0999): objective =      55.79
# SGD(0012/0012/0999): objective =      55.54
# SGD(0012/0012/0999): objective =      55.37
# SGD(0012/0012/0999): objective =      55.15
# SGD(0012/0012/0999): objective =      55.03
# SGD(0012/0012/0999): objective =      54.77
# SGD(0012/0012/0999): objective =      54.69
# SGD(0012/0012/0999): objective =      54.61
# SGD(0012/0012/0999): objective =      54.40
# SGD(0013/0013/0999): objective =      54.23
# SGD(0013/0013/0999): objective =      54.10
# SGD(0013/0013/0999): objective =      54.05
# SGD(0013/0013/0999): objective =      53.95
# SGD(0013/0013/0999): objective =      53.85
# SGD(0013/0013/0999): objective =      53.80
# SGD(0013/0013/0999): objective =      53.81
# SGD(0013/0013/0999): objective =      53.71
# SGD(0013/0013/0999): objective =      53.63
# SGD(0013/0013/0999): objective =      53.50
# SGD(0014/0014/0999): objective =      53.28
# SGD(0014/0014/0999): objective =      53.30
# SGD(0014/0014/0999): objective =      53.22
# SGD(0014/0014/0999): objective =      53.05
# SGD(0014/0014/0999): objective =      53.03
# SGD(0014/0014/0999): objective =      52.87
# SGD(0014/0014/0999): objective =      52.80
# SGD(0014/0014/0999): objective =      52.65
# SGD(0014/0014/0999): objective =      52.44
# SGD(0014/0014/0999): objective =      52.19
# SGD(0015/0015/0999): objective =      52.13
# SGD(0015/0015/0999): objective =      51.94
# SGD(0015/0015/0999): objective =      51.89
# SGD(0015/0015/0999): objective =      51.81
# SGD(0015/0015/0999): objective =      51.57
# SGD(0015/0015/0999): objective =      51.43
# SGD(0015/0015/0999): objective =      51.26
# SGD(0015/0015/0999): objective =      51.27
# SGD(0015/0015/0999): objective =      51.25
# SGD(0015/0015/0999): objective =      51.20
# SGD(0016/0016/0999): objective =      51.06
# SGD(0016/0016/0999): objective =      50.90
# SGD(0016/0016/0999): objective =      50.87
# SGD(0016/0016/0999): objective =      50.90
# SGD(0016/0016/0999): objective =      50.78
# SGD(0016/0016/0999): objective =      50.68
# SGD(0016/0016/0999): objective =      50.62
# SGD(0016/0016/0999): objective =      50.54
# SGD(0016/0016/0999): objective =      50.58
# SGD(0016/0016/0999): objective =      50.53
# SGD(0017/0017/0999): objective =      50.56
# SGD(0017/0017/0999): objective =      50.65
# SGD(0017/0017/0999): objective =      50.63
# SGD(0017/0017/0999): objective =      50.66
# SGD(0017/0017/0999): objective =      50.54
# SGD(0017/0017/0999): objective =      50.49
# SGD(0017/0017/0999): objective =      50.43
# SGD(0017/0017/0999): objective =      50.42
# SGD(0017/0017/0999): objective =      50.43
# SGD(0017/0017/0999): objective =      50.45
# SGD(0018/0018/0999): objective =      50.37
# SGD(0018/0018/0999): objective =      50.49
# SGD(0018/0018/0999): objective =      50.49
# SGD(0018/0018/0999): objective =      50.49
# SGD(0018/0018/0999): objective =      50.46
# SGD(0018/0018/0999): objective =      50.33
# SGD(0018/0018/0999): objective =      50.31
# SGD(0018/0018/0999): objective =      50.32
# SGD(0018/0018/0999): objective =      50.30
# SGD(0018/0018/0999): objective =      50.32
# SGD(0019/0019/0999): objective =      50.28
# SGD(0019/0019/0999): objective =      50.27
# SGD(0019/0019/0999): objective =      50.26
# SGD(0019/0019/0999): objective =      50.25
# SGD(0019/0019/0999): objective =      50.27
# SGD(0019/0019/0999): objective =      50.42
# SGD(0019/0019/0999): objective =      50.31
# SGD(0019/0019/0999): objective =      50.34
# SGD(0019/0019/0999): objective =      50.26
# SGD(0019/0019/0999): objective =      50.25
# SGD(0020/0020/0999): objective =      50.26
# SGD(0020/0020/0999): objective =      50.23
# SGD(0020/0020/0999): objective =      50.17
# SGD(0020/0020/0999): objective =      50.11
# SGD(0020/0020/0999): objective =      50.27
# SGD(0020/0020/0999): objective =      50.20
# SGD(0020/0020/0999): objective =      50.24
# SGD(0020/0020/0999): objective =      50.28
# SGD(0020/0020/0999): objective =      50.31
# SGD(0020/0020/0999): objective =      50.26
# SGD(0021/0021/0999): objective =      50.27
# SGD(0021/0021/0999): objective =      50.24
# SGD(0021/0021/0999): objective =      50.15
# SGD(0021/0021/0999): objective =      50.12
# SGD(0021/0021/0999): objective =      50.09
# SGD(0021/0021/0999): objective =      50.24
# SGD(0021/0021/0999): objective =      50.26
# SGD(0021/0021/0999): objective =      50.10
# SGD(0021/0021/0999): objective =      50.02
# SGD(0021/0021/0999): objective =      50.04
# SGD(0022/0022/0999): objective =      50.03
# SGD(0022/0022/0999): objective =      50.20
# SGD(0022/0022/0999): objective =      50.19
# SGD(0036/0036/0999): objective =      49.23
# SGD(0036/0036/0999): objective =      49.22
# SGD(0036/0036/0999): objective =      49.20
# SGD(0036/0036/0999): objective =      49.17
# SGD(0036/0036/0999): objective =      49.32
# SGD(0036/0036/0999): objective =      49.33
# SGD(0037/0037/0999): objective =      49.22
# SGD(0037/0037/0999): objective =      49.19
# SGD(0037/0037/0999): objective =      49.30
# SGD(0037/0037/0999): objective =      49.25
# SGD(0037/0037/0999): objective =      49.14
# SGD(0037/0037/0999): objective =      49.19
# SGD(0037/0037/0999): objective =      49.06
# SGD(0037/0037/0999): objective =      49.12
# SGD(0037/0037/0999): objective =      49.14
# SGD(0037/0037/0999): objective =      49.16
# SGD(0038/0038/0999): objective =      49.14
# SGD(0038/0038/0999): objective =      49.24
# SGD(0038/0038/0999): objective =      49.13
# SGD(0038/0038/0999): objective =      49.16
# SGD(0038/0038/0999): objective =      49.10
# SGD(0038/0038/0999): objective =      49.07
# SGD(0038/0038/0999): objective =      49.06
# SGD(0038/0038/0999): objective =      49.04
# SGD(0038/0038/0999): objective =      49.06
# SGD(0038/0038/0999): objective =      49.04
# SGD(0039/0039/0999): objective =      49.08
# SGD(0039/0039/0999): objective =      49.01
# SGD(0039/0039/0999): objective =      48.95
# SGD(0039/0039/0999): objective =      48.96
# SGD(0039/0039/0999): objective =      48.98
# SGD(0039/0039/0999): objective =      48.91
# SGD(0039/0039/0999): objective =      48.86
# SGD(0039/0039/0999): objective =      48.88
# SGD(0039/0039/0999): objective =      48.83
# SGD(0039/0039/0999): objective =      48.77
# SGD(0040/0040/0999): objective =      48.73
# SGD(0040/0040/0999): objective =      48.80
# SGD(0040/0040/0999): objective =      48.88
# SGD(0040/0040/0999): objective =      48.91
# SGD(0040/0040/0999): objective =      48.90
# SGD(0040/0040/0999): objective =      49.00
# SGD(0040/0040/0999): objective =      49.06
# SGD(0040/0040/0999): objective =      49.03
# SGD(0040/0040/0999): objective =      49.05
# SGD(0040/0040/0999): objective =      49.03
# SGD(0041/0041/0999): objective =      48.91
# SGD(0041/0041/0999): objective =      48.88
# SGD(0041/0041/0999): objective =      48.85
# SGD(0041/0041/0999): objective =      48.85
# SGD(0041/0041/0999): objective =      48.78
# SGD(0041/0041/0999): objective =      48.75
# SGD(0041/0041/0999): objective =      48.72
# SGD(0041/0041/0999): objective =      48.74
# SGD(0041/0041/0999): objective =      48.85
# SGD(0041/0041/0999): objective =      48.90
# SGD(0042/0042/0999): objective =      48.93
# SGD(0042/0042/0999): objective =      48.86
# SGD(0042/0042/0999): objective =      48.72
# SGD(0042/0042/0999): objective =      48.72
# SGD(0042/0042/0999): objective =      48.82
# SGD(0042/0042/0999): objective =      48.85
# SGD(0042/0042/0999): objective =      48.74
# SGD(0042/0042/0999): objective =      48.68
# SGD(0042/0042/0999): objective =      48.56
# SGD(0042/0042/0999): objective =      48.63
# SGD(0043/0043/0999): objective =      48.60
# SGD(0043/0043/0999): objective =      48.55
# SGD(0043/0043/0999): objective =      48.55
# SGD(0043/0043/0999): objective =      48.40
# SGD(0043/0043/0999): objective =      48.29
# SGD(0043/0043/0999): objective =      48.33
# SGD(0043/0043/0999): objective =      48.27
# SGD(0043/0043/0999): objective =      48.14
# SGD(0043/0043/0999): objective =      48.04
# SGD(0043/0043/0999): objective =      47.96
# SGD(0044/0044/0999): objective =      47.84
# SGD(0044/0044/0999): objective =      47.78
# SGD(0044/0044/0999): objective =      47.77
# SGD(0044/0044/0999): objective =      47.64
# SGD(0044/0044/0999): objective =      47.56
# SGD(0044/0044/0999): objective =      47.59
# SGD(0044/0044/0999): objective =      47.49
# SGD(0044/0044/0999): objective =      47.56
# SGD(0044/0044/0999): objective =      47.46
# SGD(0044/0044/0999): objective =      47.47
# SGD(0045/0045/0999): objective =      47.47
# SGD(0045/0045/0999): objective =      47.49
# SGD(0045/0045/0999): objective =      47.45
# SGD(0045/0045/0999): objective =      47.41
# SGD(0045/0045/0999): objective =      47.35
# SGD(0045/0045/0999): objective =      47.23
# SGD(0045/0045/0999): objective =      47.25
# SGD(0045/0045/0999): objective =      47.19
# SGD(0045/0045/0999): objective =      47.20
# SGD(0045/0045/0999): objective =      47.15
# SGD(0046/0046/0999): objective =      47.19
# SGD(0046/0046/0999): objective =      47.06
# SGD(0046/0046/0999): objective =      47.05
# SGD(0046/0046/0999): objective =      47.04
# SGD(0046/0046/0999): objective =      47.01
# SGD(0046/0046/0999): objective =      46.97
# SGD(0046/0046/0999): objective =      47.03
# SGD(0046/0046/0999): objective =      46.95
# SGD(0046/0046/0999): objective =      47.02
# SGD(0046/0046/0999): objective =      47.18
# SGD(0047/0047/0999): objective =      47.14
# SGD(0047/0047/0999): objective =      47.02
# SGD(0047/0047/0999): objective =      47.04
# SGD(0047/0047/0999): objective =      46.94
# SGD(0047/0047/0999): objective =      46.95
# SGD(0047/0047/0999): objective =      46.94
# SGD(0047/0047/0999): objective =      46.94
# SGD(0047/0047/0999): objective =      47.03
# SGD(0047/0047/0999): objective =      46.97
# SGD(0047/0047/0999): objective =      46.91
# SGD(0048/0048/0999): objective =      46.89
# SGD(0048/0048/0999): objective =      46.92
# SGD(0048/0048/0999): objective =      46.84
# SGD(0048/0048/0999): objective =      46.90
# SGD(0048/0048/0999): objective =      46.88
# SGD(0048/0048/0999): objective =      46.85
# SGD(0048/0048/0999): objective =      46.85
# SGD(0048/0048/0999): objective =      46.84
# SGD(0048/0048/0999): objective =      46.77
# SGD(0048/0048/0999): objective =      46.74
# SGD(0049/0049/0999): objective =      46.63
# SGD(0049/0049/0999): objective =      46.59
# SGD(0049/0049/0999): objective =      46.55
# SGD(0049/0049/0999): objective =      46.54
# SGD(0049/0049/0999): objective =      46.52
# SGD(0049/0049/0999): objective =      46.53
# SGD(0049/0049/0999): objective =      46.47
# SGD(0049/0049/0999): objective =      46.44
# SGD(0049/0049/0999): objective =      46.28
# SGD(0049/0049/0999): objective =      46.39
# SGD(0050/0050/0999): objective =      46.31
# SGD(0050/0050/0999): objective =      46.36
# SGD(0050/0050/0999): objective =      46.33
# SGD(0050/0050/0999): objective =      46.42
# SGD(0057/0057/0999): objective =      46.09
# SGD(0057/0057/0999): objective =      46.05
# SGD(0057/0057/0999): objective =      45.95
# SGD(0057/0057/0999): objective =      45.88
# SGD(0057/0057/0999): objective =      45.87
# SGD(0058/0058/0999): objective =      45.92
# SGD(0058/0058/0999): objective =      45.91
# SGD(0058/0058/0999): objective =      45.87
# SGD(0058/0058/0999): objective =      45.64
# SGD(0058/0058/0999): objective =      45.58
# SGD(0058/0058/0999): objective =      45.58
# SGD(0058/0058/0999): objective =      45.51
# SGD(0058/0058/0999): objective =      45.43
# SGD(0058/0058/0999): objective =      45.51
# SGD(0058/0058/0999): objective =      45.42
# SGD(0059/0059/0999): objective =      45.40
# SGD(0059/0059/0999): objective =      45.39
# SGD(0059/0059/0999): objective =      45.39
# SGD(0059/0059/0999): objective =      45.45
# SGD(0059/0059/0999): objective =      45.50
# SGD(0059/0059/0999): objective =      45.42
# SGD(0059/0059/0999): objective =      45.36
# SGD(0059/0059/0999): objective =      45.37
# SGD(0059/0059/0999): objective =      45.32
# SGD(0059/0059/0999): objective =      45.26
# SGD(0060/0060/0999): objective =      45.22
# SGD(0060/0060/0999): objective =      45.13
# SGD(0060/0060/0999): objective =      45.08
# SGD(0060/0060/0999): objective =      45.12
# SGD(0060/0060/0999): objective =      45.14
# SGD(0060/0060/0999): objective =      45.16
# SGD(0060/0060/0999): objective =      45.28
# SGD(0060/0060/0999): objective =      45.32
# SGD(0060/0060/0999): objective =      45.34
# SGD(0060/0060/0999): objective =      45.40
# SGD(0061/0061/0999): objective =      45.47
# SGD(0061/0061/0999): objective =      45.48
# SGD(0061/0061/0999): objective =      45.46
# SGD(0061/0061/0999): objective =      45.59
# SGD(0061/0061/0999): objective =      45.49
# SGD(0061/0061/0999): objective =      45.49
# SGD(0061/0061/0999): objective =      45.55
# SGD(0061/0061/0999): objective =      45.56
# SGD(0061/0061/0999): objective =      45.25
# SGD(0061/0061/0999): objective =      45.27
# SGD(0062/0062/0999): objective =      45.34
# SGD(0062/0062/0999): objective =      45.35
# SGD(0062/0062/0999): objective =      45.31
# SGD(0062/0062/0999): objective =      45.38
# SGD(0062/0062/0999): objective =      45.40
# SGD(0062/0062/0999): objective =      45.31
# SGD(0062/0062/0999): objective =      45.26
# SGD(0062/0062/0999): objective =      45.13
# SGD(0062/0062/0999): objective =      45.11
# SGD(0062/0062/0999): objective =      45.18
# SGD(0063/0063/0999): objective =      45.11
# SGD(0063/0063/0999): objective =      44.99
# SGD(0063/0063/0999): objective =      45.03
# SGD(0063/0063/0999): objective =      44.98
# SGD(0063/0063/0999): objective =      44.91
# SGD(0063/0063/0999): objective =      44.88
# SGD(0063/0063/0999): objective =      44.94
# SGD(0063/0063/0999): objective =      45.04
# SGD(0063/0063/0999): objective =      44.95
# SGD(0063/0063/0999): objective =      44.95
# SGD(0064/0064/0999): objective =      44.93
# SGD(0064/0064/0999): objective =      44.86
# SGD(0064/0064/0999): objective =      44.90
# SGD(0064/0064/0999): objective =      45.01
# SGD(0064/0064/0999): objective =      45.05
# SGD(0078/0078/0999): objective =      41.91
# SGD(0078/0078/0999): objective =      41.83
# SGD(0078/0078/0999): objective =      41.84
# SGD(0078/0078/0999): objective =      41.74
# SGD(0079/0079/0999): objective =      41.68
# SGD(0079/0079/0999): objective =      41.67
# SGD(0079/0079/0999): objective =      41.66
# SGD(0079/0079/0999): objective =      41.60
# SGD(0079/0079/0999): objective =      41.65
# SGD(0079/0079/0999): objective =      41.60
# SGD(0079/0079/0999): objective =      41.58
# SGD(0079/0079/0999): objective =      41.50
# SGD(0079/0079/0999): objective =      41.60
# SGD(0079/0079/0999): objective =      41.59
# SGD(0080/0080/0999): objective =      41.62
# SGD(0080/0080/0999): objective =      41.63
# SGD(0080/0080/0999): objective =      41.53
# SGD(0080/0080/0999): objective =      41.48
# SGD(0080/0080/0999): objective =      41.50
# SGD(0080/0080/0999): objective =      41.45
# SGD(0080/0080/0999): objective =      41.44
# SGD(0080/0080/0999): objective =      41.40
# SGD(0080/0080/0999): objective =      41.43
# SGD(0080/0080/0999): objective =      41.33
# SGD(0081/0081/0999): objective =      41.38
# SGD(0081/0081/0999): objective =      41.32
# SGD(0081/0081/0999): objective =      41.26
# SGD(0081/0081/0999): objective =      41.17
# SGD(0081/0081/0999): objective =      41.10
# SGD(0081/0081/0999): objective =      41.10
# SGD(0081/0081/0999): objective =      40.98
# SGD(0081/0081/0999): objective =      40.84
# SGD(0081/0081/0999): objective =      40.80
# SGD(0081/0081/0999): objective =      40.73
# SGD(0082/0082/0999): objective =      40.61
# SGD(0082/0082/0999): objective =      40.53
# SGD(0082/0082/0999): objective =      40.57
# SGD(0082/0082/0999): objective =      40.56
# SGD(0082/0082/0999): objective =      40.56
# SGD(0082/0082/0999): objective =      40.60
# SGD(0082/0082/0999): objective =      40.49
# SGD(0082/0082/0999): objective =      40.40
# SGD(0082/0082/0999): objective =      40.40
# SGD(0082/0082/0999): objective =      40.38
# SGD(0083/0083/0999): objective =      40.31
# SGD(0083/0083/0999): objective =      40.43
# SGD(0083/0083/0999): objective =      40.39
# SGD(0083/0083/0999): objective =      40.36
# SGD(0083/0083/0999): objective =      40.34
# SGD(0083/0083/0999): objective =      40.35
# SGD(0083/0083/0999): objective =      40.23
# SGD(0083/0083/0999): objective =      40.12
# SGD(0083/0083/0999): objective =      40.06
# SGD(0083/0083/0999): objective =      40.02
# SGD(0084/0084/0999): objective =      40.08
# SGD(0084/0084/0999): objective =      40.16
# SGD(0084/0084/0999): objective =      40.17
# SGD(0084/0084/0999): objective =      40.02
# SGD(0084/0084/0999): objective =      39.99
# SGD(0084/0084/0999): objective =      40.08
# SGD(0084/0084/0999): objective =      39.98
# SGD(0084/0084/0999): objective =      39.98
# SGD(0084/0084/0999): objective =      39.88
# SGD(0084/0084/0999): objective =      39.95
# SGD(0085/0085/0999): objective =      39.88
# SGD(0085/0085/0999): objective =      39.88
# SGD(0085/0085/0999): objective =      39.89
# SGD(0085/0085/0999): objective =      39.90
# SGD(0085/0085/0999): objective =      39.83
# SGD(0085/0085/0999): objective =      39.75
# SGD(0085/0085/0999): objective =      39.77
# SGD(0085/0085/0999): objective =      39.92
# SGD(0085/0085/0999): objective =      39.99
# SGD(0085/0085/0999): objective =      39.92
# SGD(0086/0086/0999): objective =      39.94
# SGD(0086/0086/0999): objective =      39.87
# SGD(0086/0086/0999): objective =      39.78
# SGD(0086/0086/0999): objective =      39.78
# SGD(0086/0086/0999): objective =      39.66
# SGD(0086/0086/0999): objective =      39.60
# SGD(0086/0086/0999): objective =      39.47
# SGD(0086/0086/0999): objective =      39.44
# SGD(0086/0086/0999): objective =      39.38
# SGD(0086/0086/0999): objective =      39.36
# SGD(0087/0087/0999): objective =      39.36
# SGD(0087/0087/0999): objective =      39.40
# SGD(0087/0087/0999): objective =      39.40
# SGD(0087/0087/0999): objective =      39.25
# SGD(0087/0087/0999): objective =      39.20
# SGD(0087/0087/0999): objective =      39.03
# SGD(0087/0087/0999): objective =      39.02
# SGD(0087/0087/0999): objective =      38.97
# SGD(0087/0087/0999): objective =      38.98
# SGD(0087/0087/0999): objective =      39.00
# SGD(0088/0088/0999): objective =      39.06
# SGD(0088/0088/0999): objective =      39.04
# SGD(0088/0088/0999): objective =      38.98
# SGD(0088/0088/0999): objective =      38.95
# SGD(0088/0088/0999): objective =      38.88
# SGD(0088/0088/0999): objective =      38.82
# SGD(0088/0088/0999): objective =      38.89
# SGD(0088/0088/0999): objective =      38.86
# SGD(0088/0088/0999): objective =      38.87
# SGD(0088/0088/0999): objective =      38.84
# SGD(0089/0089/0999): objective =      38.86
# SGD(0089/0089/0999): objective =      38.89
# SGD(0089/0089/0999): objective =      38.91
# SGD(0089/0089/0999): objective =      38.97
# SGD(0089/0089/0999): objective =      38.94
# SGD(0089/0089/0999): objective =      38.92
# SGD(0089/0089/0999): objective =      38.90
# SGD(0089/0089/0999): objective =      38.89
# SGD(0089/0089/0999): objective =      38.87
# SGD(0089/0089/0999): objective =      38.86
# SGD(0090/0090/0999): objective =      38.88
# SGD(0090/0090/0999): objective =      38.78
# SGD(0090/0090/0999): objective =      38.76
# SGD(0090/0090/0999): objective =      38.65
# SGD(0090/0090/0999): objective =      38.61
# SGD(0090/0090/0999): objective =      38.66
# SGD(0090/0090/0999): objective =      38.65
# SGD(0090/0090/0999): objective =      38.74
# SGD(0090/0090/0999): objective =      38.80
# SGD(0090/0090/0999): objective =      38.75
# SGD(0091/0091/0999): objective =      38.71
# SGD(0091/0091/0999): objective =      38.63
# SGD(0091/0091/0999): objective =      38.51
# SGD(0091/0091/0999): objective =      38.45
# SGD(0091/0091/0999): objective =      38.38
# SGD(0091/0091/0999): objective =      38.43
# SGD(0091/0091/0999): objective =      38.48
# SGD(0091/0091/0999): objective =      38.56
# SGD(0091/0091/0999): objective =      38.63
# SGD(0091/0091/0999): objective =      38.63
# SGD(0092/0092/0999): objective =      38.53
# SGD(0092/0092/0999): objective =      38.58
# SGD(0092/0092/0999): objective =      38.59
# SGD(0092/0092/0999): objective =      38.61
# SGD(0092/0092/0999): objective =      38.69
# SGD(0092/0092/0999): objective =      38.65
# SGD(0092/0092/0999): objective =      38.62
# SGD(0099/0099/0999): objective =      37.69
# SGD(0099/0099/0999): objective =      37.70
# SGD(0099/0099/0999): objective =      37.74
# C=0.01: Training error=47.5%
# SGD(0000/0000/0999): objective =     299.51
# SGD(0000/0000/0999): objective =     255.27
# SGD(0000/0000/0999): objective =     212.35
# SGD(0000/0000/0999): objective =     187.79
# SGD(0000/0000/0999): objective =     165.52
# SGD(0000/0000/0999): objective =     148.61
# SGD(0000/0000/0999): objective =     136.24
# SGD(0000/0000/0999): objective =     123.03
# SGD(0000/0000/0999): objective =     116.18
# SGD(0000/0000/0999): objective =     112.50
# SGD(0001/0001/0999): objective =     109.61
# SGD(0001/0001/0999): objective =     107.47
# SGD(0001/0001/0999): objective =     104.46
# SGD(0001/0001/0999): objective =     103.48
# SGD(0001/0001/0999): objective =     103.48
# SGD(0001/0001/0999): objective =     102.53
# SGD(0001/0001/0999): objective =     100.70
# SGD(0001/0001/0999): objective =      99.35
# SGD(0001/0001/0999): objective =      98.24
# SGD(0001/0001/0999): objective =      98.01
# SGD(0002/0002/0999): objective =      96.54
# SGD(0002/0002/0999): objective =      94.61
# SGD(0002/0002/0999): objective =      94.24
# SGD(0002/0002/0999): objective =      93.52
# SGD(0002/0002/0999): objective =      93.81
# SGD(0002/0002/0999): objective =      93.78
# SGD(0002/0002/0999): objective =      93.47
# SGD(0002/0002/0999): objective =      94.70
# SGD(0002/0002/0999): objective =      93.99
# SGD(0002/0002/0999): objective =      92.64
# SGD(0003/0003/0999): objective =      91.82
# SGD(0003/0003/0999): objective =      91.72
# SGD(0003/0003/0999): objective =      90.87
# SGD(0003/0003/0999): objective =      89.86
# SGD(0003/0003/0999): objective =      89.10
# SGD(0003/0003/0999): objective =      89.37
# SGD(0003/0003/0999): objective =      88.70
# SGD(0003/0003/0999): objective =      87.67
# SGD(0003/0003/0999): objective =      88.13
# SGD(0003/0003/0999): objective =      87.73
# SGD(0004/0004/0999): objective =      87.11
# SGD(0004/0004/0999): objective =      86.52
# SGD(0004/0004/0999): objective =      86.52
# SGD(0004/0004/0999): objective =      85.41
# SGD(0004/0004/0999): objective =      86.73
# SGD(0004/0004/0999): objective =      86.64
# SGD(0004/0004/0999): objective =      86.86
# SGD(0004/0004/0999): objective =      86.68
# SGD(0004/0004/0999): objective =      85.84
# SGD(0004/0004/0999): objective =      85.25
# SGD(0005/0005/0999): objective =      85.12
# SGD(0005/0005/0999): objective =      84.71
# SGD(0005/0005/0999): objective =      85.96
# SGD(0005/0005/0999): objective =      84.75
# SGD(0005/0005/0999): objective =      84.72
# SGD(0005/0005/0999): objective =      83.92
# SGD(0005/0005/0999): objective =      84.38
# SGD(0005/0005/0999): objective =      85.63
# SGD(0005/0005/0999): objective =      84.93
# SGD(0005/0005/0999): objective =      83.92
# SGD(0006/0006/0999): objective =      82.79
# SGD(0006/0006/0999): objective =      81.42
# SGD(0006/0006/0999): objective =      81.80
# SGD(0006/0006/0999): objective =      81.44
# SGD(0006/0006/0999): objective =      81.41
# SGD(0006/0006/0999): objective =      80.70
# SGD(0006/0006/0999): objective =      80.97
# SGD(0006/0006/0999): objective =      81.41
# SGD(0006/0006/0999): objective =      81.48
# SGD(0006/0006/0999): objective =      81.30
# SGD(0007/0007/0999): objective =      81.77
# SGD(0007/0007/0999): objective =      83.12
# SGD(0007/0007/0999): objective =      84.14
# SGD(0007/0007/0999): objective =      83.47
# SGD(0007/0007/0999): objective =      83.37
# SGD(0007/0007/0999): objective =      83.57
# SGD(0007/0007/0999): objective =      83.14
# SGD(0007/0007/0999): objective =      83.10
# SGD(0007/0007/0999): objective =      82.39
# SGD(0007/0007/0999): objective =      80.72
# SGD(0008/0008/0999): objective =      80.40
# SGD(0008/0008/0999): objective =      81.14
# SGD(0008/0008/0999): objective =      80.32
# SGD(0008/0008/0999): objective =      80.14
# SGD(0008/0008/0999): objective =      78.72
# SGD(0008/0008/0999): objective =      77.50
# SGD(0008/0008/0999): objective =      77.70
# SGD(0008/0008/0999): objective =      78.68
# SGD(0008/0008/0999): objective =      77.61
# SGD(0008/0008/0999): objective =      76.82
# ...
# SGD(0063/0063/0999): objective =  590403.32
# SGD(0063/0063/0999): objective =  444159.14
# SGD(0064/0064/0999): objective =  586126.61
# SGD(0064/0064/0999): objective =  607975.11
# SGD(0064/0064/0999): objective =  396409.92
# SGD(0064/0064/0999): objective =  390148.61
# SGD(0064/0064/0999): objective =  551168.62
# SGD(0064/0064/0999): objective =  373022.18
# SGD(0064/0064/0999): objective =  366435.52
# SGD(0064/0064/0999): objective =  356516.91
# SGD(0064/0064/0999): objective =  389267.39
# SGD(0064/0064/0999): objective =  441425.62
# SGD(0065/0065/0999): objective =  352060.70
# SGD(0065/0065/0999): objective =  376770.67
# SGD(0065/0065/0999): objective =  334215.54
# SGD(0065/0065/0999): objective =  348916.43
# SGD(0065/0065/0999): objective =  327935.32
# SGD(0065/0065/0999): objective =  326633.77
# SGD(0065/0065/0999): objective =  323154.67
# SGD(0065/0065/0999): objective =  325225.47
# SGD(0065/0065/0999): objective =  316848.95
# SGD(0065/0065/0999): objective =  357188.63
# SGD(0066/0066/0999): objective =  316917.49
# SGD(0066/0066/0999): objective =  316582.00
# SGD(0066/0066/0999): objective =  315021.06
# SGD(0066/0066/0999): objective =  324899.72
# SGD(0066/0066/0999): objective =  402053.13
# SGD(0066/0066/0999): objective =  499530.67
# SGD(0066/0066/0999): objective =  315107.77
# SGD(0066/0066/0999): objective =  382083.44
# SGD(0066/0066/0999): objective =  299148.81
# SGD(0066/0066/0999): objective =  294650.37
# SGD(0067/0067/0999): objective =  561598.79
# SGD(0067/0067/0999): objective =  402360.10
# SGD(0067/0067/0999): objective =  292142.45
# SGD(0067/0067/0999): objective =  333138.22
# SGD(0067/0067/0999): objective =  404230.67
# SGD(0067/0067/0999): objective =  598487.39
# SGD(0067/0067/0999): objective = 1130825.28
# SGD(0067/0067/0999): objective =  772602.71
# SGD(0067/0067/0999): objective = 2020195.67
# SGD(0067/0067/0999): objective = 1186895.64
# SGD(0068/0068/0999): objective = 12983525.03
# SGD(0068/0068/0999): objective =  742669.00
# SGD(0081/0081/0999): objective =  267844.55
# SGD(0081/0081/0999): objective =  275249.66
# SGD(0081/0081/0999): objective =  311204.05
# SGD(0082/0082/0999): objective =  269847.05
# SGD(0082/0082/0999): objective =  303895.15
# SGD(0082/0082/0999): objective =  289519.06
# SGD(0082/0082/0999): objective =  556610.91
# SGD(0082/0082/0999): objective =  313994.33
# SGD(0082/0082/0999): objective =  469367.28
# SGD(0082/0082/0999): objective =  306498.49
# SGD(0082/0082/0999): objective =  258238.02
# SGD(0082/0082/0999): objective =  303475.91
# SGD(0082/0082/0999): objective =  855888.16
# SGD(0083/0083/0999): objective = 2107134.23
# SGD(0083/0083/0999): objective = 18857695.37
# SGD(0083/0083/0999): objective =  463498.53
# SGD(0083/0083/0999): objective =  458471.53
# SGD(0083/0083/0999): objective =  754624.76
# SGD(0083/0083/0999): objective =  415883.38
# SGD(0083/0083/0999): objective =  361926.73
# SGD(0083/0083/0999): objective =  726371.16
# SGD(0083/0083/0999): objective =  786201.56
# SGD(0083/0083/0999): objective =  461353.32
# SGD(0084/0084/0999): objective =  344631.22
# SGD(0084/0084/0999): objective =  351179.91
# SGD(0084/0084/0999): objective =  332625.83
# SGD(0084/0084/0999): objective =  699408.38
# SGD(0084/0084/0999): objective = 1368098.65
# SGD(0084/0084/0999): objective =  824778.59
# SGD(0084/0084/0999): objective = 2342490.92
# SGD(0084/0084/0999): objective =  411477.99
# SGD(0084/0084/0999): objective =  372386.92
# SGD(0084/0084/0999): objective =  338326.54
# SGD(0085/0085/0999): objective =  317011.05
# SGD(0085/0085/0999): objective =  329843.86
# SGD(0085/0085/0999): objective =  336321.76
# SGD(0085/0085/0999): objective =  485419.26
# SGD(0085/0085/0999): objective =  483498.84
# SGD(0085/0085/0999): objective = 2409269.88
# SGD(0085/0085/0999): objective =  547641.61
# SGD(0085/0085/0999): objective =  393714.29
# SGD(0085/0085/0999): objective =  316685.91
# SGD(0085/0085/0999): objective =  308552.15
# SGD(0086/0086/0999): objective =  307211.28
# SGD(0086/0086/0999): objective =  723513.68
# SGD(0086/0086/0999): objective = 3930155.58
# SGD(0086/0086/0999): objective =  799270.04
# SGD(0086/0086/0999): objective = 1471423.38
# SGD(0086/0086/0999): objective =  343748.76
# SGD(0086/0086/0999): objective =  340355.15
# SGD(0086/0086/0999): objective =  482848.09
# SGD(0086/0086/0999): objective =  415378.46
# SGD(0086/0086/0999): objective =  333613.04
# SGD(0087/0087/0999): objective =  334088.56
# SGD(0087/0087/0999): objective =  331201.16
# SGD(0087/0087/0999): objective =  431120.70
# SGD(0087/0087/0999): objective =  780785.87
# SGD(0087/0087/0999): objective = 1003286.11
# SGD(0087/0087/0999): objective = 4738644.38
# SGD(0087/0087/0999): objective = 5079284.46
# SGD(0087/0087/0999): objective = 15452984.36
# SGD(0087/0087/0999): objective =  743234.52
# SGD(0087/0087/0999): objective = 1103224.22
# SGD(0088/0088/0999): objective =  621294.99
# SGD(0088/0088/0999): objective =  540737.76
# SGD(0088/0088/0999): objective =  621718.02
# SGD(0088/0088/0999): objective =  510472.19
# SGD(0088/0088/0999): objective =  477651.08
# SGD(0088/0088/0999): objective =  630056.40
# SGD(0088/0088/0999): objective =  503929.92
# SGD(0088/0088/0999): objective =  459454.84
# SGD(0088/0088/0999): objective =  719114.98
# SGD(0088/0088/0999): objective =  637359.94
# SGD(0089/0089/0999): objective =  474232.92
# SGD(0089/0089/0999): objective =  581043.92
# SGD(0089/0089/0999): objective =  431232.79
# SGD(0089/0089/0999): objective =  430974.87
# SGD(0089/0089/0999): objective =  401244.37
# SGD(0089/0089/0999): objective =  415936.01
# SGD(0089/0089/0999): objective =  631599.15
# SGD(0089/0089/0999): objective =  378429.05
# SGD(0089/0089/0999): objective =  381573.83
# SGD(0089/0089/0999): objective =  382401.43
# SGD(0090/0090/0999): objective =  410862.83
# SGD(0090/0090/0999): objective =  423580.31
# SGD(0090/0090/0999): objective =  541084.22
# SGD(0090/0090/0999): objective =  348405.34
# SGD(0090/0090/0999): objective =  466620.90
# SGD(0090/0090/0999): objective =  357731.33
# SGD(0090/0090/0999): objective =  372540.51
# SGD(0090/0090/0999): objective =  395494.36
# SGD(0090/0090/0999): objective =  352794.83
# SGD(0090/0090/0999): objective =  351330.98
# SGD(0091/0091/0999): objective =  323176.21
# SGD(0091/0091/0999): objective =  368127.25
# SGD(0091/0091/0999): objective =  478979.64
# SGD(0091/0091/0999): objective =  318055.16
# SGD(0091/0091/0999): objective =  399425.92
# SGD(0091/0091/0999): objective =  333334.61
# SGD(0091/0091/0999): objective =  328257.96
# SGD(0091/0091/0999): objective =  296096.38
# SGD(0091/0091/0999): objective =  297253.79
# SGD(0091/0091/0999): objective =  365548.03
# SGD(0092/0092/0999): objective =  351893.83
# SGD(0092/0092/0999): objective =  321306.45
# SGD(0092/0092/0999): objective =  286932.59
# SGD(0092/0092/0999): objective =  329820.69
# SGD(0092/0092/0999): objective =  797613.77
# SGD(0092/0092/0999): objective = 1125813.90
# SGD(0092/0092/0999): objective =  447396.10
# SGD(0092/0092/0999): objective =  292653.33
# SGD(0092/0092/0999): objective =  309369.79
# SGD(0092/0092/0999): objective =  705986.37
# SGD(0093/0093/0999): objective =  551344.21
# SGD(0093/0093/0999): objective = 1202551.22
# SGD(0093/0093/0999): objective =  636956.89
# SGD(0093/0093/0999): objective = 1108115.19
# SGD(0093/0093/0999): objective =  482080.50
# SGD(0093/0093/0999): objective =  331600.53
# SGD(0093/0093/0999): objective =  309253.15
# SGD(0093/0093/0999): objective =  351842.87
# SGD(0093/0093/0999): objective =  313806.33
# SGD(0093/0093/0999): objective =  331884.47
# SGD(0094/0094/0999): objective =  344099.74
# SGD(0094/0094/0999): objective =  336805.49
# SGD(0094/0094/0999): objective = 1447027.54
# SGD(0094/0094/0999): objective = 7560196.19
# SGD(0094/0094/0999): objective = 1687055.53
# SGD(0094/0094/0999): objective = 6313867.86
# SGD(0094/0094/0999): objective =  409524.49
# SGD(0094/0094/0999): objective =  422720.79
# SGD(0094/0094/0999): objective =  535725.08
# SGD(0094/0094/0999): objective =  445830.57
# SGD(0095/0095/0999): objective =  414985.90
# SGD(0095/0095/0999): objective =  412755.50
# SGD(0095/0095/0999): objective =  353030.26
# SGD(0095/0095/0999): objective =  372357.42
# SGD(0095/0095/0999): objective =  391362.04
# SGD(0095/0095/0999): objective =  422834.27
# SGD(0095/0095/0999): objective =  326378.79
# SGD(0095/0095/0999): objective =  322660.85
# SGD(0095/0095/0999): objective =  361228.17
# SGD(0095/0095/0999): objective =  359397.58
# SGD(0096/0096/0999): objective =  339502.81
# SGD(0096/0096/0999): objective =  307691.39
# SGD(0096/0096/0999): objective =  328426.99
# SGD(0096/0096/0999): objective =  328679.62
# SGD(0096/0096/0999): objective =  452848.18
# SGD(0096/0096/0999): objective =  449520.71
# SGD(0096/0096/0999): objective =  349712.66
# SGD(0096/0096/0999): objective =  287317.64
# SGD(0096/0096/0999): objective =  418238.42
# SGD(0096/0096/0999): objective =  290827.45
# SGD(0097/0097/0999): objective =  419743.45
# SGD(0097/0097/0999): objective =  295398.28
# SGD(0097/0097/0999): objective =  331205.75
# SGD(0097/0097/0999): objective =  305851.09
# SGD(0097/0097/0999): objective =  273564.40
# SGD(0097/0097/0999): objective =  278468.44
# SGD(0097/0097/0999): objective =  278659.27
# SGD(0097/0097/0999): objective =  316131.90
# SGD(0097/0097/0999): objective =  258829.99
# SGD(0097/0097/0999): objective =  355304.29
# SGD(0098/0098/0999): objective =  523527.83
# SGD(0098/0098/0999): objective = 3194833.86
# SGD(0098/0098/0999): objective = 8300402.73
# SGD(0098/0098/0999): objective = 22005858.13
# SGD(0098/0098/0999): objective = 1312403.54
# SGD(0098/0098/0999): objective =  617797.03
# SGD(0098/0098/0999): objective =  491864.04
# SGD(0098/0098/0999): objective =  547142.44
# SGD(0098/0098/0999): objective =  473416.72
# SGD(0098/0098/0999): objective =  474958.76
# SGD(0099/0099/0999): objective =  442678.07
# SGD(0099/0099/0999): objective =  438221.38
# SGD(0099/0099/0999): objective =  455602.44
# SGD(0099/0099/0999): objective =  540244.41
# SGD(0099/0099/0999): objective =  591156.42
# SGD(0099/0099/0999): objective =  814789.04
# SGD(0099/0099/0999): objective =  501709.00
# SGD(0099/0099/0999): objective =  382716.80
# SGD(0099/0099/0999): objective =  540923.06
# SGD(0099/0099/0999): objective =  458817.50
# C=100: Training error=5.2%

# %%
#   Training error for each C value is printed above
plt.figure(2);
plt.plot(C_vector, training_errors, marker='o')
plt.xscale('log')
plt.xlabel('C (log scale)')
plt.ylabel('Training Error (%)')
plt.title('Training Error vs C for SVM')
plt.grid()
plt.show()

# %%
# Objective value convergence for different C values
plt.figure(3)
for i, C in enumerate(C_vector):
    plt.plot(objectives_list[i], label=f"C={C}")
plt.xlabel('Iteration')
plt.ylabel('Objective Value')
plt.title('Objective Value Convergence for Different C Values')
plt.legend()
plt.show()

# %% [markdown]
# The training error decreases as **C** increases, which is expected, since a larger **C** gives more weight to minimizing classification errors on the training set. However, the **objective value** curves show that for larger values of **C**, the optimization becomes less steady, with more visible peaks and oscillations. In contrast, smaller values of **C** lead to smoother and more stable convergence, but usually with a higher training error.
